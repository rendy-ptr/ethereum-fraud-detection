# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import GridSearchCV, StratifiedKFold
from catboost import CatBoostClassifier, Pool
from sklearn.metrics import accuracy_score, recall_score, precision_score, f1_score, roc_auc_score

# %%
x_tr_resample = pd.read_csv('../../Data/clean/X_train_smote.csv')
X_test = pd.read_csv('../../Data/clean/X_test.csv')
y_tr_resample = np.loadtxt("../../Data/clean/y_train_smote.csv", delimiter=",")
y_test = np.loadtxt("../../Data/clean/y_test.csv", delimiter=",")

# %%
skf_grid = StratifiedKFold(n_splits=10, shuffle=True, random_state=42)

# %%
base_params = {
    'task_type': 'GPU',
    'devices': '0:1',  # Gunakan GPU pertama
    'gpu_ram_part': 0.95,  # Gunakan 95% memory GPU yang tersedia
}

# %%
catboost_params = {
    'iterations': [500],             # Kurangi iterasi untuk mempercepat proses
    'depth': [6],                    # Gunakan kedalaman pohon tunggal
    'learning_rate': [0.05],         # Gunakan 1 nilai yang moderat
    'l2_leaf_reg': [3],              # Tetapkan 1 nilai regularisasi
    'border_count': [128],           # Nilai optimal untuk GPU
    'bootstrap_type': ['Bernoulli'], # Pertahankan bootstrap Bernoulli
    'subsample': [0.8],              # Satu nilai subsample
    'grow_policy': ['SymmetricTree'],# Pertahankan kebijakan cepat
    'eval_metric': ['AUC'],          # Gunakan AUC sebagai metrik evaluasi
    'od_type': ['Iter'],             # Early stopping
    'od_wait': [30],                 # Kurangi iterasi tanpa peningkatan
}

# %%
init_params = base_params.copy()

# %%
model = CatBoostClassifier(**init_params)

# %%
grid_search = GridSearchCV(
        estimator=model,
        param_grid=catboost_params,
        cv=skf_grid,
        n_jobs=1,  # Gunakan 1 karena kita menggunakan GPU
        verbose=1,
        scoring='f1_weighted',
)

# %%
train_pool = Pool(x_tr_resample, y_tr_resample)

# %%
grid_search.fit(x_tr_resample, y_tr_resample)
# Out:
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Default metric period is 5 because AUC is/are not implemented for GPU
# 0:	total: 381ms	remaining: 3m 10s
# 1:	total: 619ms	remaining: 2m 34s
# 2:	total: 726ms	remaining: 2m
# 3:	total: 817ms	remaining: 1m 41s
# 4:	total: 917ms	remaining: 1m 30s
# 5:	total: 1.03s	remaining: 1m 24s
# 6:	total: 1.12s	remaining: 1m 18s
# 7:	total: 1.21s	remaining: 1m 14s
# 8:	total: 1.3s	remaining: 1m 11s
# 9:	total: 1.39s	remaining: 1m 8s
# 10:	total: 1.52s	remaining: 1m 7s
# 11:	total: 1.66s	remaining: 1m 7s
# 12:	total: 1.76s	remaining: 1m 5s
# 13:	total: 1.92s	remaining: 1m 6s
# 14:	total: 2.05s	remaining: 1m 6s
# 15:	total: 2.14s	remaining: 1m 4s
# 16:	total: 2.23s	remaining: 1m 3s
# 17:	total: 2.32s	remaining: 1m 2s
# 18:	total: 2.4s	remaining: 1m
# 19:	total: 2.48s	remaining: 59.5s
# 20:	total: 2.55s	remaining: 58.3s
# 21:	total: 2.64s	remaining: 57.3s
# 22:	total: 2.72s	remaining: 56.4s
# 23:	total: 2.79s	remaining: 55.4s
# 24:	total: 2.9s	remaining: 55s
# 25:	total: 2.98s	remaining: 54.4s
# 26:	total: 3.08s	remaining: 53.9s
# 27:	total: 3.18s	remaining: 53.7s
# 28:	total: 3.28s	remaining: 53.2s
# 29:	total: 3.36s	remaining: 52.7s
# 30:	total: 3.46s	remaining: 52.3s
# 31:	total: 3.55s	remaining: 52s
# 32:	total: 3.66s	remaining: 51.7s
# 33:	total: 3.97s	remaining: 54.4s
# 34:	total: 4.06s	remaining: 54s
# 35:	total: 4.2s	remaining: 54.1s
# 36:	total: 4.33s	remaining: 54.1s
# 37:	total: 4.46s	remaining: 54.3s
# 38:	total: 4.58s	remaining: 54.1s
# 39:	total: 4.72s	remaining: 54.3s
# 40:	total: 4.86s	remaining: 54.4s
# 41:	total: 4.99s	remaining: 54.4s
# 42:	total: 5.12s	remaining: 54.4s
# 43:	total: 5.25s	remaining: 54.4s
# 44:	total: 5.4s	remaining: 54.6s
# 45:	total: 5.53s	remaining: 54.6s
# 46:	total: 5.67s	remaining: 54.7s
# 47:	total: 5.8s	remaining: 54.7s
# 48:	total: 5.94s	remaining: 54.7s
# 49:	total: 6.09s	remaining: 54.8s
# 50:	total: 6.23s	remaining: 54.8s
# 51:	total: 6.37s	remaining: 54.9s
# 52:	total: 6.51s	remaining: 54.9s
# 53:	total: 6.66s	remaining: 55s
# 54:	total: 6.8s	remaining: 55s
# 55:	total: 6.95s	remaining: 55.1s
# 56:	total: 7.1s	remaining: 55.2s
# 57:	total: 7.22s	remaining: 55s
# 58:	total: 7.36s	remaining: 55s
# 59:	total: 7.5s	remaining: 55s
# 60:	total: 7.64s	remaining: 55s
# 61:	total: 7.78s	remaining: 55s
# 62:	total: 7.91s	remaining: 54.9s
# 63:	total: 8.04s	remaining: 54.8s
# 64:	total: 8.19s	remaining: 54.8s
# 65:	total: 8.35s	remaining: 54.9s
# 66:	total: 8.51s	remaining: 55s
# 67:	total: 8.63s	remaining: 54.9s
# 68:	total: 8.77s	remaining: 54.8s
# 69:	total: 9.23s	remaining: 56.7s
# 70:	total: 9.5s	remaining: 57.4s
# 71:	total: 9.63s	remaining: 57.2s
# 72:	total: 9.76s	remaining: 57.1s
# 73:	total: 9.85s	remaining: 56.7s
# 74:	total: 9.92s	remaining: 56.2s
# 75:	total: 10s	remaining: 55.8s
# 76:	total: 10.1s	remaining: 55.5s
# 77:	total: 10.2s	remaining: 55.1s
# 78:	total: 10.3s	remaining: 54.7s
# 79:	total: 10.3s	remaining: 54.3s
# 80:	total: 10.4s	remaining: 54s
# 81:	total: 10.5s	remaining: 53.7s
# 82:	total: 10.6s	remaining: 53.4s
# 83:	total: 10.7s	remaining: 53.1s
# 84:	total: 10.8s	remaining: 52.8s
# 85:	total: 10.9s	remaining: 52.6s
# 86:	total: 11s	remaining: 52.3s
# 87:	total: 11.1s	remaining: 51.9s
# 88:	total: 11.2s	remaining: 51.6s
# 89:	total: 11.2s	remaining: 51.2s
# 90:	total: 11.3s	remaining: 50.9s
# 91:	total: 11.4s	remaining: 50.5s
# 92:	total: 11.5s	remaining: 50.2s
# 93:	total: 11.6s	remaining: 50s
# 94:	total: 11.7s	remaining: 49.7s
# 95:	total: 11.8s	remaining: 49.5s
# 96:	total: 11.8s	remaining: 49.2s
# 97:	total: 11.9s	remaining: 48.9s
# 98:	total: 12s	remaining: 48.6s
# 99:	total: 12.1s	remaining: 48.3s
# 100:	total: 12.2s	remaining: 48s
# 101:	total: 12.2s	remaining: 47.8s
# 102:	total: 12.3s	remaining: 47.5s
# 103:	total: 12.4s	remaining: 47.3s
# 104:	total: 12.6s	remaining: 47.6s
# 105:	total: 12.9s	remaining: 47.8s
# 106:	total: 12.9s	remaining: 47.5s
# 107:	total: 13s	remaining: 47.2s
# 108:	total: 13.1s	remaining: 47s
# 109:	total: 13.2s	remaining: 46.8s
# 110:	total: 13.3s	remaining: 46.5s
# 111:	total: 13.4s	remaining: 46.3s
# 112:	total: 13.5s	remaining: 46.1s
# 113:	total: 13.6s	remaining: 45.9s
# 114:	total: 13.6s	remaining: 45.6s
# 115:	total: 13.7s	remaining: 45.4s
# 116:	total: 13.8s	remaining: 45.1s
# 117:	total: 13.9s	remaining: 44.9s
# 118:	total: 14s	remaining: 44.7s
# 119:	total: 14.1s	remaining: 44.6s
# 120:	total: 14.2s	remaining: 44.4s
# 121:	total: 14.2s	remaining: 44.1s
# 122:	total: 14.3s	remaining: 43.9s
# 123:	total: 14.4s	remaining: 43.7s
# 124:	total: 14.5s	remaining: 43.5s
# 125:	total: 14.6s	remaining: 43.3s
# 126:	total: 14.7s	remaining: 43.1s
# 127:	total: 14.7s	remaining: 42.8s
# 128:	total: 14.8s	remaining: 42.7s
# 129:	total: 14.9s	remaining: 42.5s
# 130:	total: 15s	remaining: 42.3s
# 131:	total: 15.1s	remaining: 42.1s
# 132:	total: 15.2s	remaining: 41.9s
# 133:	total: 15.3s	remaining: 41.8s
# 134:	total: 15.4s	remaining: 41.6s
# 135:	total: 15.5s	remaining: 41.4s
# 136:	total: 15.6s	remaining: 41.3s
# 137:	total: 15.7s	remaining: 41.2s
# 138:	total: 15.8s	remaining: 41.2s
# 139:	total: 16s	remaining: 41.2s
# 140:	total: 16.2s	remaining: 41.2s
# 141:	total: 16.4s	remaining: 41.4s
# 142:	total: 17s	remaining: 42.4s
# 143:	total: 17.1s	remaining: 42.2s
# 144:	total: 17.2s	remaining: 42.1s
# 145:	total: 17.3s	remaining: 42.1s
# 146:	total: 17.5s	remaining: 42s
# 147:	total: 17.6s	remaining: 42s
# 148:	total: 17.8s	remaining: 41.8s
# 149:	total: 17.9s	remaining: 41.7s
# 150:	total: 18s	remaining: 41.7s
# 151:	total: 18.2s	remaining: 41.7s
# 152:	total: 18.4s	remaining: 41.7s
# 153:	total: 18.5s	remaining: 41.5s
# 154:	total: 18.5s	remaining: 41.3s
# 155:	total: 18.7s	remaining: 41.1s
# 156:	total: 18.8s	remaining: 41s
# 157:	total: 18.9s	remaining: 40.8s
# 158:	total: 19s	remaining: 40.7s
# 159:	total: 19.1s	remaining: 40.5s
# 160:	total: 19.1s	remaining: 40.3s
# 161:	total: 19.2s	remaining: 40.1s
# 162:	total: 19.3s	remaining: 40s
# 163:	total: 19.4s	remaining: 39.8s
# 164:	total: 19.5s	remaining: 39.7s
# 165:	total: 19.6s	remaining: 39.5s
# 166:	total: 19.7s	remaining: 39.3s
# 167:	total: 19.8s	remaining: 39.2s
# 168:	total: 19.9s	remaining: 39s
# 169:	total: 20s	remaining: 38.8s
# 170:	total: 20.1s	remaining: 38.6s
# 171:	total: 20.2s	remaining: 38.4s
# 172:	total: 20.6s	remaining: 38.9s
# 173:	total: 20.7s	remaining: 38.7s
# 174:	total: 20.7s	remaining: 38.5s
# 175:	total: 20.8s	remaining: 38.3s
# 176:	total: 20.9s	remaining: 38.1s
# 177:	total: 21s	remaining: 37.9s
# 178:	total: 21.1s	remaining: 37.7s
# 179:	total: 21.1s	remaining: 37.6s
# 180:	total: 21.2s	remaining: 37.4s
# 181:	total: 21.3s	remaining: 37.3s
# 182:	total: 21.4s	remaining: 37.1s
# 183:	total: 21.5s	remaining: 37s
# 184:	total: 21.6s	remaining: 36.8s
# 185:	total: 21.7s	remaining: 36.7s
# 186:	total: 21.8s	remaining: 36.5s
# 187:	total: 21.9s	remaining: 36.3s
# 188:	total: 22s	remaining: 36.2s
# 189:	total: 22.1s	remaining: 36s
# 190:	total: 22.1s	remaining: 35.8s
# 191:	total: 22.2s	remaining: 35.6s
# 192:	total: 22.3s	remaining: 35.5s
# 193:	total: 22.4s	remaining: 35.3s
# 194:	total: 22.5s	remaining: 35.1s
# 195:	total: 22.6s	remaining: 35s
# 196:	total: 22.7s	remaining: 34.8s
# 197:	total: 22.8s	remaining: 34.7s
# 198:	total: 22.9s	remaining: 34.6s
# 199:	total: 22.9s	remaining: 34.4s
# 200:	total: 23.1s	remaining: 34.4s
# 201:	total: 23.4s	remaining: 34.5s
# 202:	total: 23.5s	remaining: 34.4s
# 203:	total: 23.5s	remaining: 34.2s
# 204:	total: 23.6s	remaining: 34s
# 205:	total: 23.7s	remaining: 33.8s
# 206:	total: 23.8s	remaining: 33.7s
# 207:	total: 23.9s	remaining: 33.5s
# 208:	total: 24s	remaining: 33.4s
# 209:	total: 24.1s	remaining: 33.2s
# 210:	total: 24.2s	remaining: 33.1s
# 211:	total: 24.3s	remaining: 33s
# 212:	total: 24.4s	remaining: 32.8s
# 213:	total: 24.4s	remaining: 32.7s
# 214:	total: 24.5s	remaining: 32.5s
# 215:	total: 24.6s	remaining: 32.4s
# 216:	total: 24.7s	remaining: 32.2s
# 217:	total: 24.8s	remaining: 32.1s
# 218:	total: 24.9s	remaining: 31.9s
# 219:	total: 25s	remaining: 31.8s
# 220:	total: 25.1s	remaining: 31.7s
# 221:	total: 25.1s	remaining: 31.5s
# 222:	total: 25.2s	remaining: 31.3s
# 223:	total: 25.3s	remaining: 31.2s
# 224:	total: 25.4s	remaining: 31s
# 225:	total: 25.5s	remaining: 30.9s
# 226:	total: 25.5s	remaining: 30.7s
# 227:	total: 25.6s	remaining: 30.5s
# 228:	total: 25.7s	remaining: 30.4s
# 229:	total: 25.7s	remaining: 30.2s
# 230:	total: 26s	remaining: 30.3s
# 231:	total: 26.1s	remaining: 30.1s
# 232:	total: 26.2s	remaining: 30s
# 233:	total: 26.3s	remaining: 29.9s
# 234:	total: 26.4s	remaining: 29.7s
# 235:	total: 26.5s	remaining: 29.6s
# 236:	total: 26.6s	remaining: 29.5s
# 237:	total: 26.7s	remaining: 29.4s
# 238:	total: 26.8s	remaining: 29.2s
# 239:	total: 26.9s	remaining: 29.1s
# 240:	total: 26.9s	remaining: 28.9s
# 241:	total: 27s	remaining: 28.8s
# 242:	total: 27.1s	remaining: 28.7s
# 243:	total: 27.2s	remaining: 28.5s
# 244:	total: 27.3s	remaining: 28.4s
# 245:	total: 27.4s	remaining: 28.3s
# 246:	total: 27.5s	remaining: 28.1s
# 247:	total: 27.6s	remaining: 28s
# 248:	total: 27.7s	remaining: 27.9s
# 249:	total: 27.8s	remaining: 27.8s
# 250:	total: 27.9s	remaining: 27.6s
# 251:	total: 27.9s	remaining: 27.5s
# 252:	total: 28s	remaining: 27.4s
# 253:	total: 28.1s	remaining: 27.2s
# 254:	total: 28.2s	remaining: 27.1s
# 255:	total: 28.3s	remaining: 27s
# 256:	total: 28.4s	remaining: 26.9s
# 257:	total: 28.5s	remaining: 26.7s
# 258:	total: 28.7s	remaining: 26.7s
# 259:	total: 28.8s	remaining: 26.6s
# 260:	total: 28.9s	remaining: 26.5s
# 261:	total: 28.9s	remaining: 26.3s
# 262:	total: 29s	remaining: 26.2s
# 263:	total: 29.1s	remaining: 26s
# 264:	total: 29.2s	remaining: 25.9s
# 265:	total: 29.3s	remaining: 25.8s
# 266:	total: 29.4s	remaining: 25.6s
# 267:	total: 29.5s	remaining: 25.5s
# 268:	total: 29.5s	remaining: 25.4s
# 269:	total: 29.6s	remaining: 25.2s
# 270:	total: 29.7s	remaining: 25.1s
# 271:	total: 29.8s	remaining: 25s
# 272:	total: 29.9s	remaining: 24.8s
# 273:	total: 30s	remaining: 24.7s
# 274:	total: 30.1s	remaining: 24.6s
# 275:	total: 30.1s	remaining: 24.5s
# 276:	total: 30.2s	remaining: 24.3s
# 277:	total: 30.3s	remaining: 24.2s
# 278:	total: 30.4s	remaining: 24.1s
# 279:	total: 30.5s	remaining: 24s
# 280:	total: 30.6s	remaining: 23.8s
# 281:	total: 30.7s	remaining: 23.7s
# 282:	total: 30.8s	remaining: 23.6s
# 283:	total: 30.9s	remaining: 23.5s
# 284:	total: 31s	remaining: 23.4s
# 285:	total: 31.1s	remaining: 23.2s
# 286:	total: 31.2s	remaining: 23.2s
# 287:	total: 31.5s	remaining: 23.2s
# 288:	total: 31.6s	remaining: 23s
# 289:	total: 31.6s	remaining: 22.9s
# 290:	total: 31.7s	remaining: 22.8s
# 291:	total: 31.8s	remaining: 22.6s
# 292:	total: 31.9s	remaining: 22.5s
# 293:	total: 31.9s	remaining: 22.4s
# 294:	total: 32s	remaining: 22.3s
# 295:	total: 32.1s	remaining: 22.1s
# 296:	total: 32.2s	remaining: 22s
# 297:	total: 32.3s	remaining: 21.9s
# 298:	total: 32.4s	remaining: 21.8s
# 299:	total: 32.5s	remaining: 21.6s
# 300:	total: 32.6s	remaining: 21.5s
# 301:	total: 32.7s	remaining: 21.4s
# 302:	total: 32.8s	remaining: 21.3s
# 303:	total: 32.8s	remaining: 21.2s
# 304:	total: 32.9s	remaining: 21.1s
# 305:	total: 33s	remaining: 20.9s
# 306:	total: 33.1s	remaining: 20.8s
# 307:	total: 33.2s	remaining: 20.7s
# 308:	total: 33.3s	remaining: 20.6s
# 309:	total: 33.4s	remaining: 20.5s
# 310:	total: 33.5s	remaining: 20.4s
# 311:	total: 33.6s	remaining: 20.2s
# 312:	total: 33.7s	remaining: 20.1s
# 313:	total: 33.7s	remaining: 20s
# 314:	total: 33.8s	remaining: 19.9s
# 315:	total: 34s	remaining: 19.8s
# 316:	total: 34.2s	remaining: 19.8s
# 317:	total: 34.3s	remaining: 19.6s
# 318:	total: 34.4s	remaining: 19.5s
# 319:	total: 34.5s	remaining: 19.4s
# 320:	total: 34.6s	remaining: 19.3s
# 321:	total: 34.6s	remaining: 19.1s
# 322:	total: 34.7s	remaining: 19s
# 323:	total: 34.8s	remaining: 18.9s
# 324:	total: 34.9s	remaining: 18.8s
# 325:	total: 35s	remaining: 18.7s
# 326:	total: 35.1s	remaining: 18.6s
# 327:	total: 35.2s	remaining: 18.5s
# 328:	total: 35.3s	remaining: 18.3s
# 329:	total: 35.4s	remaining: 18.2s
# 330:	total: 35.5s	remaining: 18.1s
# 331:	total: 35.6s	remaining: 18s
# 332:	total: 35.6s	remaining: 17.9s
# 333:	total: 35.7s	remaining: 17.8s
# 334:	total: 35.8s	remaining: 17.6s
# 335:	total: 35.9s	remaining: 17.5s
# 336:	total: 36s	remaining: 17.4s
# 337:	total: 36.1s	remaining: 17.3s
# 338:	total: 36.2s	remaining: 17.2s
# 339:	total: 36.3s	remaining: 17.1s
# 340:	total: 36.4s	remaining: 17s
# 341:	total: 36.5s	remaining: 16.8s
# 342:	total: 36.6s	remaining: 16.7s
# 343:	total: 36.7s	remaining: 16.6s
# 344:	total: 36.9s	remaining: 16.6s
# 345:	total: 37s	remaining: 16.5s
# 346:	total: 37.1s	remaining: 16.4s
# 347:	total: 37.1s	remaining: 16.2s
# 348:	total: 37.2s	remaining: 16.1s
# 349:	total: 37.3s	remaining: 16s
# 350:	total: 37.4s	remaining: 15.9s
# 351:	total: 37.5s	remaining: 15.8s
# 352:	total: 37.6s	remaining: 15.6s
# 353:	total: 37.6s	remaining: 15.5s
# 354:	total: 37.7s	remaining: 15.4s
# 355:	total: 37.8s	remaining: 15.3s
# 356:	total: 37.9s	remaining: 15.2s
# 357:	total: 37.9s	remaining: 15s
# 358:	total: 38s	remaining: 14.9s
# 359:	total: 38.1s	remaining: 14.8s
# 360:	total: 38.2s	remaining: 14.7s
# 361:	total: 38.3s	remaining: 14.6s
# 362:	total: 38.4s	remaining: 14.5s
# 363:	total: 38.5s	remaining: 14.4s
# 364:	total: 38.6s	remaining: 14.3s
# 365:	total: 38.8s	remaining: 14.2s
# 366:	total: 38.9s	remaining: 14.1s
# 367:	total: 39s	remaining: 14s
# 368:	total: 39.2s	remaining: 13.9s
# 369:	total: 39.3s	remaining: 13.8s
# 370:	total: 39.4s	remaining: 13.7s
# 371:	total: 39.6s	remaining: 13.6s
# 372:	total: 39.7s	remaining: 13.5s
# 373:	total: 40.2s	remaining: 13.6s
# 374:	total: 40.4s	remaining: 13.5s
# 375:	total: 40.5s	remaining: 13.3s
# 376:	total: 40.6s	remaining: 13.2s
# 377:	total: 40.7s	remaining: 13.1s
# 378:	total: 40.9s	remaining: 13s
# 379:	total: 41s	remaining: 13s
# 380:	total: 41.1s	remaining: 12.9s
# 381:	total: 41.3s	remaining: 12.7s
# 382:	total: 41.4s	remaining: 12.6s
# 383:	total: 41.4s	remaining: 12.5s
# 384:	total: 41.5s	remaining: 12.4s
# 385:	total: 41.6s	remaining: 12.3s
# 386:	total: 41.7s	remaining: 12.2s
# 387:	total: 41.7s	remaining: 12.1s
# 388:	total: 41.8s	remaining: 11.9s
# 389:	total: 41.9s	remaining: 11.8s
# 390:	total: 42s	remaining: 11.7s
# 391:	total: 42.1s	remaining: 11.6s
# 392:	total: 42.2s	remaining: 11.5s
# 393:	total: 42.3s	remaining: 11.4s
# 394:	total: 42.4s	remaining: 11.3s
# 395:	total: 42.5s	remaining: 11.1s
# 396:	total: 42.5s	remaining: 11s
# 397:	total: 42.6s	remaining: 10.9s
# 398:	total: 42.7s	remaining: 10.8s
# 399:	total: 42.8s	remaining: 10.7s
# 400:	total: 42.9s	remaining: 10.6s
# 401:	total: 42.9s	remaining: 10.5s
# 402:	total: 43s	remaining: 10.4s
# 403:	total: 43.1s	remaining: 10.2s
# 404:	total: 43.2s	remaining: 10.1s
# 405:	total: 43.3s	remaining: 10s
# 406:	total: 43.4s	remaining: 9.91s
# 407:	total: 43.4s	remaining: 9.8s
# 408:	total: 43.5s	remaining: 9.69s
# 409:	total: 43.6s	remaining: 9.57s
# 410:	total: 43.7s	remaining: 9.46s
# 411:	total: 43.8s	remaining: 9.35s
# 412:	total: 43.9s	remaining: 9.24s
# 413:	total: 44s	remaining: 9.13s
# 414:	total: 44.1s	remaining: 9.03s
# 415:	total: 44.2s	remaining: 8.92s
# 416:	total: 44.3s	remaining: 8.81s
# 417:	total: 44.4s	remaining: 8.7s
# 418:	total: 44.4s	remaining: 8.59s
# 419:	total: 44.5s	remaining: 8.48s
# 420:	total: 44.6s	remaining: 8.38s
# 421:	total: 44.7s	remaining: 8.27s
# 422:	total: 44.9s	remaining: 8.16s
# 423:	total: 44.9s	remaining: 8.05s
# 424:	total: 45s	remaining: 7.94s
# 425:	total: 45s	remaining: 7.83s
# 426:	total: 45.1s	remaining: 7.72s
# 427:	total: 45.2s	remaining: 7.61s
# 428:	total: 45.3s	remaining: 7.5s
# 429:	total: 45.4s	remaining: 7.4s
# 430:	total: 45.5s	remaining: 7.29s
# 431:	total: 45.6s	remaining: 7.18s
# 432:	total: 45.7s	remaining: 7.08s
# 433:	total: 45.9s	remaining: 6.97s
# 434:	total: 45.9s	remaining: 6.87s
# 435:	total: 46s	remaining: 6.76s
# 436:	total: 46.1s	remaining: 6.65s
# 437:	total: 46.2s	remaining: 6.54s
# 438:	total: 46.3s	remaining: 6.44s
# 439:	total: 46.4s	remaining: 6.33s
# 440:	total: 46.5s	remaining: 6.23s
# 441:	total: 46.6s	remaining: 6.12s
# 442:	total: 46.7s	remaining: 6.01s
# 443:	total: 46.8s	remaining: 5.9s
# 444:	total: 46.9s	remaining: 5.79s
# 445:	total: 47s	remaining: 5.69s
# 446:	total: 47.1s	remaining: 5.58s
# 447:	total: 47.2s	remaining: 5.48s
# 448:	total: 47.3s	remaining: 5.37s
# 449:	total: 47.4s	remaining: 5.27s
# 450:	total: 47.5s	remaining: 5.16s
# 451:	total: 47.6s	remaining: 5.06s
# 452:	total: 47.7s	remaining: 4.95s
# 453:	total: 47.8s	remaining: 4.85s
# 454:	total: 48s	remaining: 4.75s
# 455:	total: 48.1s	remaining: 4.64s
# 456:	total: 48.2s	remaining: 4.53s
# 457:	total: 48.3s	remaining: 4.42s
# 458:	total: 48.3s	remaining: 4.32s
# 459:	total: 48.4s	remaining: 4.21s
# 460:	total: 48.5s	remaining: 4.11s
# 461:	total: 48.6s	remaining: 4s
# 462:	total: 48.7s	remaining: 3.89s
# 463:	total: 48.8s	remaining: 3.79s
# 464:	total: 48.9s	remaining: 3.68s
# 465:	total: 49s	remaining: 3.58s
# 466:	total: 49.1s	remaining: 3.47s
# 467:	total: 49.2s	remaining: 3.37s
# 468:	total: 49.3s	remaining: 3.26s
# 469:	total: 49.4s	remaining: 3.15s
# 470:	total: 49.5s	remaining: 3.05s
# 471:	total: 49.6s	remaining: 2.94s
# 472:	total: 49.7s	remaining: 2.84s
# 473:	total: 49.8s	remaining: 2.73s
# 474:	total: 49.9s	remaining: 2.63s
# 475:	total: 50s	remaining: 2.52s
# 476:	total: 50.1s	remaining: 2.41s
# 477:	total: 50.2s	remaining: 2.31s
# 478:	total: 50.3s	remaining: 2.2s
# 479:	total: 50.4s	remaining: 2.1s
# 480:	total: 50.5s	remaining: 1.99s
# 481:	total: 50.6s	remaining: 1.89s
# 482:	total: 50.7s	remaining: 1.78s
# 483:	total: 50.8s	remaining: 1.68s
# 484:	total: 50.9s	remaining: 1.57s
# 485:	total: 51s	remaining: 1.47s
# 486:	total: 51.2s	remaining: 1.36s
# 487:	total: 51.2s	remaining: 1.26s
# 488:	total: 51.3s	remaining: 1.15s
# 489:	total: 51.4s	remaining: 1.05s
# 490:	total: 51.5s	remaining: 944ms
# 491:	total: 51.6s	remaining: 839ms
# 492:	total: 51.7s	remaining: 734ms
# 493:	total: 51.8s	remaining: 629ms
# 494:	total: 51.9s	remaining: 524ms
# 495:	total: 52s	remaining: 419ms
# 496:	total: 52s	remaining: 314ms
# 497:	total: 52.1s	remaining: 209ms
# 498:	total: 52.2s	remaining: 105ms
# 499:	total: 52.3s	remaining: 0us
# Default metric period is 5 because AUC is/are not implemented for GPU
# 0:	total: 85ms	remaining: 42.4s
# 1:	total: 178ms	remaining: 44.3s
# 2:	total: 276ms	remaining: 45.7s
# 3:	total: 368ms	remaining: 45.7s
# 4:	total: 459ms	remaining: 45.4s
# 5:	total: 554ms	remaining: 45.6s
# 6:	total: 650ms	remaining: 45.8s
# 7:	total: 720ms	remaining: 44.3s
# 8:	total: 816ms	remaining: 44.5s
# 9:	total: 911ms	remaining: 44.6s
# 10:	total: 1.01s	remaining: 45s
# 11:	total: 1.08s	remaining: 44s
# 12:	total: 1.17s	remaining: 43.9s
# 13:	total: 1.3s	remaining: 45.3s
# 14:	total: 1.47s	remaining: 47.5s
# 15:	total: 1.53s	remaining: 46.5s
# 16:	total: 1.6s	remaining: 45.6s
# 17:	total: 1.69s	remaining: 45.3s
# 18:	total: 1.79s	remaining: 45.2s
# 19:	total: 1.89s	remaining: 45.3s
# 20:	total: 1.98s	remaining: 45.2s
# 21:	total: 2.07s	remaining: 44.9s
# 22:	total: 2.17s	remaining: 44.9s
# 23:	total: 2.26s	remaining: 44.9s
# 24:	total: 2.36s	remaining: 44.8s
# 25:	total: 2.45s	remaining: 44.7s
# 26:	total: 2.55s	remaining: 44.6s
# 27:	total: 2.65s	remaining: 44.7s
# 28:	total: 2.74s	remaining: 44.5s
# 29:	total: 2.82s	remaining: 44.2s
# 30:	total: 2.92s	remaining: 44.2s
# 31:	total: 3.01s	remaining: 44.1s
# 32:	total: 3.12s	remaining: 44.1s
# 33:	total: 3.21s	remaining: 44.1s
# 34:	total: 3.32s	remaining: 44.1s
# 35:	total: 3.42s	remaining: 44.1s
# 36:	total: 3.51s	remaining: 43.9s
# 37:	total: 3.6s	remaining: 43.7s
# 38:	total: 3.7s	remaining: 43.7s
# 39:	total: 3.8s	remaining: 43.7s
# 40:	total: 3.9s	remaining: 43.7s
# 41:	total: 3.99s	remaining: 43.5s
# 42:	total: 4.07s	remaining: 43.3s
# 43:	total: 4.15s	remaining: 43s
# 44:	total: 4.22s	remaining: 42.7s
# 45:	total: 4.28s	remaining: 42.3s
# 46:	total: 4.38s	remaining: 42.2s
# 47:	total: 4.47s	remaining: 42.1s
# 48:	total: 4.63s	remaining: 42.7s
# 49:	total: 4.87s	remaining: 43.8s
# 50:	total: 4.95s	remaining: 43.5s
# 51:	total: 5.01s	remaining: 43.2s
# 52:	total: 5.1s	remaining: 43s
# 53:	total: 5.18s	remaining: 42.8s
# 54:	total: 5.27s	remaining: 42.7s
# 55:	total: 5.36s	remaining: 42.5s
# 56:	total: 5.46s	remaining: 42.4s
# 57:	total: 5.55s	remaining: 42.3s
# 58:	total: 5.63s	remaining: 42.1s
# 59:	total: 5.72s	remaining: 42s
# 60:	total: 5.81s	remaining: 41.8s
# 61:	total: 5.91s	remaining: 41.7s
# 62:	total: 6s	remaining: 41.6s
# 63:	total: 6.08s	remaining: 41.4s
# 64:	total: 6.17s	remaining: 41.3s
# 65:	total: 6.25s	remaining: 41.1s
# 66:	total: 6.33s	remaining: 40.9s
# 67:	total: 6.42s	remaining: 40.8s
# 68:	total: 6.53s	remaining: 40.8s
# 69:	total: 6.61s	remaining: 40.6s
# 70:	total: 6.68s	remaining: 40.4s
# 71:	total: 6.76s	remaining: 40.2s
# 72:	total: 6.85s	remaining: 40s
# 73:	total: 6.93s	remaining: 39.9s
# 74:	total: 7.02s	remaining: 39.8s
# 75:	total: 7.1s	remaining: 39.6s
# 76:	total: 7.21s	remaining: 39.6s
# 77:	total: 7.38s	remaining: 40s
# 78:	total: 7.59s	remaining: 40.5s
# 79:	total: 7.66s	remaining: 40.2s
# 80:	total: 7.73s	remaining: 40s
# 81:	total: 7.81s	remaining: 39.8s
# 82:	total: 7.89s	remaining: 39.6s
# 83:	total: 7.96s	remaining: 39.4s
# 84:	total: 8.04s	remaining: 39.3s
# 85:	total: 8.12s	remaining: 39.1s
# 86:	total: 8.2s	remaining: 38.9s
# 87:	total: 8.3s	remaining: 38.9s
# 88:	total: 8.38s	remaining: 38.7s
# 89:	total: 8.46s	remaining: 38.5s
# 90:	total: 8.59s	remaining: 38.6s
# 91:	total: 8.74s	remaining: 38.8s
# 92:	total: 8.88s	remaining: 38.9s
# 93:	total: 9.02s	remaining: 38.9s
# 94:	total: 9.16s	remaining: 39s
# 95:	total: 9.3s	remaining: 39.1s
# 96:	total: 9.44s	remaining: 39.2s
# 97:	total: 9.58s	remaining: 39.3s
# 98:	total: 9.72s	remaining: 39.4s
# 99:	total: 9.86s	remaining: 39.4s
# 100:	total: 10s	remaining: 39.7s
# 101:	total: 10.2s	remaining: 39.8s
# 102:	total: 10.3s	remaining: 39.8s
# 103:	total: 10.5s	remaining: 39.8s
# 104:	total: 10.6s	remaining: 40s
# 105:	total: 10.8s	remaining: 40.1s
# 106:	total: 10.9s	remaining: 40s
# 107:	total: 11s	remaining: 40s
# 108:	total: 11.2s	remaining: 40.1s
# 109:	total: 11.3s	remaining: 40.1s
# 110:	total: 11.5s	remaining: 40.2s
# 111:	total: 11.6s	remaining: 40.2s
# 112:	total: 11.7s	remaining: 40.2s
# 113:	total: 11.9s	remaining: 40.3s
# 114:	total: 12s	remaining: 40.3s
# 115:	total: 12.2s	remaining: 40.3s
# 116:	total: 12.3s	remaining: 40.4s
# 117:	total: 12.5s	remaining: 40.4s
# 118:	total: 12.6s	remaining: 40.4s
# 119:	total: 12.8s	remaining: 40.4s
# 120:	total: 13.2s	remaining: 41.4s
# 121:	total: 13.5s	remaining: 41.7s
# 122:	total: 13.6s	remaining: 41.7s
# 123:	total: 13.7s	remaining: 41.7s
# 124:	total: 13.9s	remaining: 41.7s
# 125:	total: 14.1s	remaining: 41.7s
# 126:	total: 14.2s	remaining: 41.7s
# 127:	total: 14.3s	remaining: 41.6s
# 128:	total: 14.4s	remaining: 41.4s
# 129:	total: 14.5s	remaining: 41.2s
# 130:	total: 14.6s	remaining: 41.1s
# 131:	total: 14.7s	remaining: 40.9s
# 132:	total: 14.8s	remaining: 40.8s
# 133:	total: 14.9s	remaining: 40.6s
# 134:	total: 15s	remaining: 40.5s
# 135:	total: 15.1s	remaining: 40.3s
# 136:	total: 15.2s	remaining: 40.2s
# 137:	total: 15.3s	remaining: 40.1s
# 138:	total: 15.4s	remaining: 39.9s
# 139:	total: 15.5s	remaining: 39.8s
# 140:	total: 15.6s	remaining: 39.6s
# 141:	total: 15.7s	remaining: 39.5s
# 142:	total: 15.8s	remaining: 39.3s
# 143:	total: 15.8s	remaining: 39.2s
# 144:	total: 15.9s	remaining: 39s
# 145:	total: 16.1s	remaining: 38.9s
# 146:	total: 16.1s	remaining: 38.8s
# 147:	total: 16.3s	remaining: 38.6s
# 148:	total: 16.4s	remaining: 38.5s
# 149:	total: 16.5s	remaining: 38.4s
# 150:	total: 16.6s	remaining: 38.3s
# 151:	total: 16.7s	remaining: 38.2s
# 152:	total: 16.8s	remaining: 38.1s
# 153:	total: 16.9s	remaining: 37.9s
# 154:	total: 16.9s	remaining: 37.7s
# 155:	total: 17s	remaining: 37.6s
# 156:	total: 17.1s	remaining: 37.5s
# 157:	total: 17.2s	remaining: 37.3s
# 158:	total: 17.3s	remaining: 37.1s
# 159:	total: 17.4s	remaining: 37s
# 160:	total: 17.5s	remaining: 36.8s
# 161:	total: 17.6s	remaining: 36.7s
# 162:	total: 17.7s	remaining: 36.5s
# 163:	total: 17.7s	remaining: 36.4s
# 164:	total: 17.8s	remaining: 36.2s
# 165:	total: 17.9s	remaining: 36.1s
# 166:	total: 18s	remaining: 36s
# 167:	total: 18.1s	remaining: 35.9s
# 168:	total: 18.3s	remaining: 35.8s
# 169:	total: 18.4s	remaining: 35.6s
# 170:	total: 18.4s	remaining: 35.5s
# 171:	total: 18.5s	remaining: 35.3s
# 172:	total: 18.6s	remaining: 35.1s
# 173:	total: 18.7s	remaining: 35s
# 174:	total: 18.8s	remaining: 34.9s
# 175:	total: 18.9s	remaining: 34.7s
# 176:	total: 19s	remaining: 34.6s
# 177:	total: 19.1s	remaining: 34.5s
# 178:	total: 19.2s	remaining: 34.3s
# 179:	total: 19.3s	remaining: 34.2s
# 180:	total: 19.4s	remaining: 34.1s
# 181:	total: 19.5s	remaining: 34s
# 182:	total: 19.5s	remaining: 33.9s
# 183:	total: 19.7s	remaining: 33.8s
# 184:	total: 19.8s	remaining: 33.7s
# 185:	total: 19.9s	remaining: 33.6s
# 186:	total: 20s	remaining: 33.5s
# 187:	total: 20.1s	remaining: 33.4s
# 188:	total: 20.2s	remaining: 33.2s
# 189:	total: 20.3s	remaining: 33.1s
# 190:	total: 20.4s	remaining: 33s
# 191:	total: 20.5s	remaining: 32.9s
# 192:	total: 20.6s	remaining: 32.8s
# 193:	total: 20.7s	remaining: 32.6s
# 194:	total: 20.9s	remaining: 32.7s
# 195:	total: 21.2s	remaining: 32.8s
# 196:	total: 21.2s	remaining: 32.6s
# 197:	total: 21.3s	remaining: 32.5s
# 198:	total: 21.4s	remaining: 32.3s
# 199:	total: 21.5s	remaining: 32.2s
# 200:	total: 21.6s	remaining: 32.1s
# 201:	total: 21.6s	remaining: 31.9s
# 202:	total: 21.7s	remaining: 31.8s
# 203:	total: 21.8s	remaining: 31.7s
# 204:	total: 21.9s	remaining: 31.6s
# 205:	total: 22s	remaining: 31.4s
# 206:	total: 22.1s	remaining: 31.3s
# 207:	total: 22.2s	remaining: 31.2s
# 208:	total: 22.3s	remaining: 31.1s
# 209:	total: 22.4s	remaining: 30.9s
# 210:	total: 22.5s	remaining: 30.8s
# 211:	total: 22.6s	remaining: 30.7s
# 212:	total: 22.7s	remaining: 30.5s
# 213:	total: 22.7s	remaining: 30.4s
# 214:	total: 22.8s	remaining: 30.3s
# 215:	total: 22.9s	remaining: 30.1s
# 216:	total: 23s	remaining: 30s
# 217:	total: 23.1s	remaining: 29.9s
# 218:	total: 23.2s	remaining: 29.8s
# 219:	total: 23.3s	remaining: 29.7s
# 220:	total: 23.4s	remaining: 29.5s
# 221:	total: 23.5s	remaining: 29.4s
# 222:	total: 23.6s	remaining: 29.3s
# 223:	total: 23.7s	remaining: 29.2s
# 224:	total: 23.9s	remaining: 29.2s
# 225:	total: 24.1s	remaining: 29.2s
# 226:	total: 24.2s	remaining: 29.1s
# 227:	total: 24.3s	remaining: 29s
# 228:	total: 24.3s	remaining: 28.8s
# 229:	total: 24.4s	remaining: 28.6s
# 230:	total: 24.5s	remaining: 28.5s
# 231:	total: 24.5s	remaining: 28.4s
# 232:	total: 24.6s	remaining: 28.2s
# 233:	total: 24.7s	remaining: 28.1s
# 234:	total: 24.8s	remaining: 28s
# 235:	total: 24.9s	remaining: 27.9s
# 236:	total: 25s	remaining: 27.8s
# 237:	total: 25.1s	remaining: 27.6s
# 238:	total: 25.2s	remaining: 27.5s
# 239:	total: 25.3s	remaining: 27.4s
# 240:	total: 25.4s	remaining: 27.3s
# 241:	total: 25.5s	remaining: 27.1s
# 242:	total: 25.5s	remaining: 27s
# 243:	total: 25.6s	remaining: 26.9s
# 244:	total: 25.7s	remaining: 26.7s
# 245:	total: 25.8s	remaining: 26.6s
# 246:	total: 25.9s	remaining: 26.5s
# 247:	total: 26.1s	remaining: 26.5s
# 248:	total: 26.2s	remaining: 26.4s
# 249:	total: 26.3s	remaining: 26.3s
# 250:	total: 26.5s	remaining: 26.3s
# 251:	total: 26.6s	remaining: 26.2s
# 252:	total: 26.8s	remaining: 26.1s
# 253:	total: 26.9s	remaining: 26.1s
# 254:	total: 27.1s	remaining: 26s
# 255:	total: 27.4s	remaining: 26.1s
# 256:	total: 27.8s	remaining: 26.3s
# 257:	total: 27.9s	remaining: 26.2s
# 258:	total: 28s	remaining: 26.1s
# 259:	total: 28.2s	remaining: 26s
# 260:	total: 28.3s	remaining: 26s
# 261:	total: 28.5s	remaining: 25.9s
# 262:	total: 28.6s	remaining: 25.8s
# 263:	total: 28.7s	remaining: 25.7s
# 264:	total: 28.8s	remaining: 25.5s
# 265:	total: 28.9s	remaining: 25.4s
# 266:	total: 29s	remaining: 25.3s
# 267:	total: 29.1s	remaining: 25.2s
# 268:	total: 29.2s	remaining: 25.1s
# 269:	total: 29.3s	remaining: 24.9s
# 270:	total: 29.4s	remaining: 24.8s
# 271:	total: 29.5s	remaining: 24.7s
# 272:	total: 29.6s	remaining: 24.6s
# 273:	total: 29.7s	remaining: 24.5s
# 274:	total: 29.7s	remaining: 24.3s
# 275:	total: 29.8s	remaining: 24.2s
# 276:	total: 29.9s	remaining: 24.1s
# 277:	total: 30s	remaining: 23.9s
# 278:	total: 30.1s	remaining: 23.8s
# 279:	total: 30.2s	remaining: 23.7s
# 280:	total: 30.2s	remaining: 23.6s
# 281:	total: 30.3s	remaining: 23.4s
# 282:	total: 30.4s	remaining: 23.3s
# 283:	total: 30.5s	remaining: 23.2s
# 284:	total: 30.6s	remaining: 23.1s
# 285:	total: 30.7s	remaining: 23s
# 286:	total: 31s	remaining: 23s
# 287:	total: 31.1s	remaining: 22.9s
# 288:	total: 31.1s	remaining: 22.7s
# 289:	total: 31.2s	remaining: 22.6s
# 290:	total: 31.3s	remaining: 22.5s
# 291:	total: 31.4s	remaining: 22.4s
# 292:	total: 31.5s	remaining: 22.2s
# 293:	total: 31.6s	remaining: 22.1s
# 294:	total: 31.7s	remaining: 22s
# 295:	total: 31.8s	remaining: 21.9s
# 296:	total: 31.9s	remaining: 21.8s
# 297:	total: 31.9s	remaining: 21.7s
# 298:	total: 32s	remaining: 21.5s
# 299:	total: 32.1s	remaining: 21.4s
# 300:	total: 32.2s	remaining: 21.3s
# 301:	total: 32.3s	remaining: 21.2s
# 302:	total: 32.4s	remaining: 21.1s
# 303:	total: 32.5s	remaining: 20.9s
# 304:	total: 32.6s	remaining: 20.8s
# 305:	total: 32.7s	remaining: 20.7s
# 306:	total: 32.8s	remaining: 20.6s
# 307:	total: 32.9s	remaining: 20.5s
# 308:	total: 33s	remaining: 20.4s
# 309:	total: 33.1s	remaining: 20.3s
# 310:	total: 33.1s	remaining: 20.1s
# 311:	total: 33.2s	remaining: 20s
# 312:	total: 33.3s	remaining: 19.9s
# 313:	total: 33.4s	remaining: 19.8s
# 314:	total: 33.6s	remaining: 19.7s
# 315:	total: 33.7s	remaining: 19.6s
# 316:	total: 33.7s	remaining: 19.5s
# 317:	total: 33.8s	remaining: 19.3s
# 318:	total: 33.9s	remaining: 19.2s
# 319:	total: 33.9s	remaining: 19.1s
# 320:	total: 34s	remaining: 19s
# 321:	total: 34.1s	remaining: 18.9s
# 322:	total: 34.2s	remaining: 18.8s
# 323:	total: 34.3s	remaining: 18.6s
# 324:	total: 34.4s	remaining: 18.5s
# 325:	total: 34.5s	remaining: 18.4s
# 326:	total: 34.6s	remaining: 18.3s
# 327:	total: 34.7s	remaining: 18.2s
# 328:	total: 34.8s	remaining: 18.1s
# 329:	total: 34.8s	remaining: 18s
# 330:	total: 34.9s	remaining: 17.8s
# 331:	total: 35s	remaining: 17.7s
# 332:	total: 35.1s	remaining: 17.6s
# 333:	total: 35.1s	remaining: 17.5s
# 334:	total: 35.2s	remaining: 17.3s
# 335:	total: 35.3s	remaining: 17.2s
# 336:	total: 35.4s	remaining: 17.1s
# 337:	total: 35.5s	remaining: 17s
# 338:	total: 35.6s	remaining: 16.9s
# 339:	total: 35.7s	remaining: 16.8s
# 340:	total: 35.8s	remaining: 16.7s
# 341:	total: 35.9s	remaining: 16.6s
# 342:	total: 35.9s	remaining: 16.4s
# 343:	total: 36.1s	remaining: 16.4s
# 344:	total: 36.3s	remaining: 16.3s
# 345:	total: 36.4s	remaining: 16.2s
# 346:	total: 36.5s	remaining: 16.1s
# 347:	total: 36.5s	remaining: 16s
# 348:	total: 36.6s	remaining: 15.9s
# 349:	total: 36.7s	remaining: 15.7s
# 350:	total: 36.8s	remaining: 15.6s
# 351:	total: 36.9s	remaining: 15.5s
# 352:	total: 37s	remaining: 15.4s
# 353:	total: 37.1s	remaining: 15.3s
# 354:	total: 37.2s	remaining: 15.2s
# 355:	total: 37.3s	remaining: 15.1s
# 356:	total: 37.4s	remaining: 15s
# 357:	total: 37.5s	remaining: 14.9s
# 358:	total: 37.5s	remaining: 14.7s
# 359:	total: 37.6s	remaining: 14.6s
# 360:	total: 37.7s	remaining: 14.5s
# 361:	total: 37.8s	remaining: 14.4s
# 362:	total: 37.9s	remaining: 14.3s
# 363:	total: 38s	remaining: 14.2s
# 364:	total: 38.1s	remaining: 14.1s
# 365:	total: 38.2s	remaining: 14s
# 366:	total: 38.3s	remaining: 13.9s
# 367:	total: 38.4s	remaining: 13.8s
# 368:	total: 38.5s	remaining: 13.7s
# 369:	total: 38.6s	remaining: 13.5s
# 370:	total: 38.7s	remaining: 13.4s
# 371:	total: 38.8s	remaining: 13.3s
# 372:	total: 39s	remaining: 13.3s
# 373:	total: 39.1s	remaining: 13.2s
# 374:	total: 39.2s	remaining: 13.1s
# 375:	total: 39.3s	remaining: 12.9s
# 376:	total: 39.3s	remaining: 12.8s
# 377:	total: 39.4s	remaining: 12.7s
# 378:	total: 39.5s	remaining: 12.6s
# 379:	total: 39.6s	remaining: 12.5s
# 380:	total: 39.7s	remaining: 12.4s
# 381:	total: 39.8s	remaining: 12.3s
# 382:	total: 39.8s	remaining: 12.2s
# 383:	total: 39.9s	remaining: 12.1s
# 384:	total: 40s	remaining: 12s
# 385:	total: 40.1s	remaining: 11.8s
# 386:	total: 40.2s	remaining: 11.7s
# 387:	total: 40.2s	remaining: 11.6s
# 388:	total: 40.3s	remaining: 11.5s
# 389:	total: 40.4s	remaining: 11.4s
# 390:	total: 40.5s	remaining: 11.3s
# 391:	total: 40.5s	remaining: 11.2s
# 392:	total: 40.6s	remaining: 11.1s
# 393:	total: 40.7s	remaining: 11s
# 394:	total: 40.8s	remaining: 10.8s
# 395:	total: 40.9s	remaining: 10.7s
# 396:	total: 41s	remaining: 10.6s
# 397:	total: 41s	remaining: 10.5s
# 398:	total: 41.1s	remaining: 10.4s
# 399:	total: 41.2s	remaining: 10.3s
# 400:	total: 41.3s	remaining: 10.2s
# 401:	total: 41.4s	remaining: 10.1s
# 402:	total: 41.5s	remaining: 9.98s
# 403:	total: 41.5s	remaining: 9.87s
# 404:	total: 41.6s	remaining: 9.76s
# 405:	total: 41.7s	remaining: 9.64s
# 406:	total: 41.7s	remaining: 9.54s
# 407:	total: 42s	remaining: 9.46s
# 408:	total: 42.1s	remaining: 9.36s
# 409:	total: 42.2s	remaining: 9.26s
# 410:	total: 42.2s	remaining: 9.14s
# 411:	total: 42.3s	remaining: 9.03s
# 412:	total: 42.3s	remaining: 8.92s
# 413:	total: 42.4s	remaining: 8.81s
# 414:	total: 42.5s	remaining: 8.7s
# 415:	total: 42.6s	remaining: 8.6s
# 416:	total: 42.7s	remaining: 8.49s
# 417:	total: 42.7s	remaining: 8.38s
# 418:	total: 42.8s	remaining: 8.28s
# 419:	total: 42.9s	remaining: 8.18s
# 420:	total: 43.1s	remaining: 8.09s
# 421:	total: 43.2s	remaining: 7.99s
# 422:	total: 43.4s	remaining: 7.89s
# 423:	total: 43.5s	remaining: 7.8s
# 424:	total: 43.6s	remaining: 7.7s
# 425:	total: 43.8s	remaining: 7.61s
# 426:	total: 43.9s	remaining: 7.51s
# 427:	total: 44.1s	remaining: 7.41s
# 428:	total: 44.2s	remaining: 7.31s
# 429:	total: 44.3s	remaining: 7.21s
# 430:	total: 44.4s	remaining: 7.12s
# 431:	total: 44.6s	remaining: 7.02s
# 432:	total: 44.8s	remaining: 6.92s
# 433:	total: 44.9s	remaining: 6.83s
# 434:	total: 45s	remaining: 6.73s
# 435:	total: 45.2s	remaining: 6.63s
# 436:	total: 45.3s	remaining: 6.53s
# 437:	total: 45.4s	remaining: 6.43s
# 438:	total: 45.5s	remaining: 6.33s
# 439:	total: 45.7s	remaining: 6.23s
# 440:	total: 45.8s	remaining: 6.13s
# 441:	total: 45.9s	remaining: 6.03s
# 442:	total: 46.1s	remaining: 5.93s
# 443:	total: 46.2s	remaining: 5.82s
# 444:	total: 46.2s	remaining: 5.71s
# 445:	total: 46.3s	remaining: 5.6s
# 446:	total: 46.3s	remaining: 5.5s
# 447:	total: 46.4s	remaining: 5.39s
# 448:	total: 46.5s	remaining: 5.28s
# 449:	total: 46.6s	remaining: 5.17s
# 450:	total: 46.7s	remaining: 5.07s
# 451:	total: 46.7s	remaining: 4.96s
# 452:	total: 46.8s	remaining: 4.86s
# 453:	total: 46.9s	remaining: 4.75s
# 454:	total: 47s	remaining: 4.64s
# 455:	total: 47.1s	remaining: 4.54s
# 456:	total: 47.1s	remaining: 4.44s
# 457:	total: 47.2s	remaining: 4.33s
# 458:	total: 47.3s	remaining: 4.22s
# 459:	total: 47.4s	remaining: 4.12s
# 460:	total: 47.5s	remaining: 4.01s
# 461:	total: 47.5s	remaining: 3.91s
# 462:	total: 47.6s	remaining: 3.8s
# 463:	total: 47.7s	remaining: 3.7s
# 464:	total: 47.7s	remaining: 3.59s
# 465:	total: 47.8s	remaining: 3.49s
# 466:	total: 47.9s	remaining: 3.38s
# 467:	total: 48s	remaining: 3.28s
# 468:	total: 48.1s	remaining: 3.18s
# 469:	total: 48.1s	remaining: 3.07s
# 470:	total: 48.2s	remaining: 2.97s
# 471:	total: 48.3s	remaining: 2.86s
# 472:	total: 48.4s	remaining: 2.76s
# 473:	total: 48.4s	remaining: 2.66s
# 474:	total: 48.5s	remaining: 2.55s
# 475:	total: 48.6s	remaining: 2.45s
# 476:	total: 48.7s	remaining: 2.35s
# 477:	total: 48.8s	remaining: 2.24s
# 478:	total: 48.8s	remaining: 2.14s
# 479:	total: 48.9s	remaining: 2.04s
# 480:	total: 49s	remaining: 1.94s
# 481:	total: 49.1s	remaining: 1.83s
# 482:	total: 49.2s	remaining: 1.73s
# 483:	total: 49.2s	remaining: 1.63s
# 484:	total: 49.3s	remaining: 1.52s
# 485:	total: 49.4s	remaining: 1.42s
# 486:	total: 49.5s	remaining: 1.32s
# 487:	total: 49.6s	remaining: 1.22s
# 488:	total: 49.6s	remaining: 1.12s
# 489:	total: 49.7s	remaining: 1.01s
# 490:	total: 49.8s	remaining: 913ms
# 491:	total: 49.9s	remaining: 811ms
# 492:	total: 50s	remaining: 710ms
# 493:	total: 50.1s	remaining: 608ms
# 494:	total: 50.1s	remaining: 507ms
# 495:	total: 50.2s	remaining: 405ms
# 496:	total: 50.3s	remaining: 304ms
# 497:	total: 50.4s	remaining: 202ms
# 498:	total: 50.5s	remaining: 101ms
# 499:	total: 50.5s	remaining: 0us
# Default metric period is 5 because AUC is/are not implemented for GPU
# 0:	total: 89.4ms	remaining: 44.6s
# 1:	total: 166ms	remaining: 41.3s
# 2:	total: 258ms	remaining: 42.8s
# 3:	total: 361ms	remaining: 44.8s
# 4:	total: 429ms	remaining: 42.5s
# 5:	total: 491ms	remaining: 40.4s
# 6:	total: 576ms	remaining: 40.6s
# 7:	total: 667ms	remaining: 41s
# 8:	total: 757ms	remaining: 41.3s
# 9:	total: 875ms	remaining: 42.9s
# 10:	total: 963ms	remaining: 42.8s
# 11:	total: 1.03s	remaining: 42s
# 12:	total: 1.1s	remaining: 41.2s
# 13:	total: 1.16s	remaining: 40.4s
# 14:	total: 1.23s	remaining: 39.7s
# 15:	total: 1.3s	remaining: 39.4s
# 16:	total: 1.37s	remaining: 39s
# 17:	total: 1.47s	remaining: 39.3s
# 18:	total: 1.54s	remaining: 39s
# 19:	total: 1.61s	remaining: 38.6s
# 20:	total: 1.68s	remaining: 38.3s
# 21:	total: 1.75s	remaining: 38s
# 22:	total: 1.84s	remaining: 38.1s
# 23:	total: 1.93s	remaining: 38.3s
# 24:	total: 2.02s	remaining: 38.3s
# 25:	total: 2.1s	remaining: 38.2s
# 26:	total: 2.16s	remaining: 37.9s
# 27:	total: 2.24s	remaining: 37.8s
# 28:	total: 2.32s	remaining: 37.7s
# 29:	total: 2.4s	remaining: 37.7s
# 30:	total: 2.47s	remaining: 37.4s
# 31:	total: 2.53s	remaining: 37s
# 32:	total: 2.61s	remaining: 36.9s
# 33:	total: 2.69s	remaining: 36.8s
# 34:	total: 2.75s	remaining: 36.6s
# 35:	total: 2.84s	remaining: 36.6s
# 36:	total: 2.92s	remaining: 36.6s
# 37:	total: 3.01s	remaining: 36.6s
# 38:	total: 3.12s	remaining: 36.9s
# 39:	total: 3.19s	remaining: 36.7s
# 40:	total: 3.28s	remaining: 36.7s
# 41:	total: 3.36s	remaining: 36.7s
# 42:	total: 3.5s	remaining: 37.2s
# 43:	total: 3.65s	remaining: 37.8s
# 44:	total: 3.8s	remaining: 38.4s
# 45:	total: 3.95s	remaining: 39s
# 46:	total: 4.08s	remaining: 39.4s
# 47:	total: 4.21s	remaining: 39.7s
# 48:	total: 4.34s	remaining: 39.9s
# 49:	total: 4.47s	remaining: 40.3s
# 50:	total: 4.59s	remaining: 40.4s
# 51:	total: 4.73s	remaining: 40.7s
# 52:	total: 4.84s	remaining: 40.8s
# 53:	total: 4.98s	remaining: 41.1s
# 54:	total: 5.12s	remaining: 41.4s
# 55:	total: 5.28s	remaining: 41.8s
# 56:	total: 5.43s	remaining: 42.2s
# 57:	total: 5.57s	remaining: 42.5s
# 58:	total: 5.72s	remaining: 42.8s
# 59:	total: 5.86s	remaining: 43s
# 60:	total: 6.01s	remaining: 43.3s
# 61:	total: 6.19s	remaining: 43.7s
# 62:	total: 6.34s	remaining: 44s
# 63:	total: 6.5s	remaining: 44.3s
# 64:	total: 6.64s	remaining: 44.4s
# 65:	total: 6.79s	remaining: 44.6s
# 66:	total: 6.92s	remaining: 44.7s
# 67:	total: 7.06s	remaining: 44.9s
# 68:	total: 7.21s	remaining: 45s
# 69:	total: 7.35s	remaining: 45.2s
# 70:	total: 7.49s	remaining: 45.3s
# 71:	total: 7.63s	remaining: 45.3s
# 72:	total: 7.77s	remaining: 45.4s
# 73:	total: 7.91s	remaining: 45.5s
# 74:	total: 8.04s	remaining: 45.5s
# 75:	total: 8.19s	remaining: 45.7s
# 76:	total: 8.33s	remaining: 45.8s
# 77:	total: 8.47s	remaining: 45.8s
# 78:	total: 8.61s	remaining: 45.9s
# 79:	total: 8.74s	remaining: 45.9s
# 80:	total: 8.89s	remaining: 46s
# 81:	total: 9.05s	remaining: 46.1s
# 82:	total: 9.16s	remaining: 46s
# 83:	total: 9.27s	remaining: 45.9s
# 84:	total: 9.38s	remaining: 45.8s
# 85:	total: 9.48s	remaining: 45.6s
# 86:	total: 9.58s	remaining: 45.5s
# 87:	total: 9.68s	remaining: 45.3s
# 88:	total: 9.77s	remaining: 45.1s
# 89:	total: 9.86s	remaining: 44.9s
# 90:	total: 9.94s	remaining: 44.7s
# 91:	total: 10s	remaining: 44.6s
# 92:	total: 10.1s	remaining: 44.4s
# 93:	total: 10.2s	remaining: 44.2s
# 94:	total: 10.3s	remaining: 44s
# 95:	total: 10.4s	remaining: 43.8s
# 96:	total: 10.5s	remaining: 43.7s
# 97:	total: 10.6s	remaining: 43.5s
# 98:	total: 10.7s	remaining: 43.4s
# 99:	total: 10.8s	remaining: 43.2s
# 100:	total: 10.9s	remaining: 43s
# 101:	total: 11s	remaining: 42.8s
# 102:	total: 11.1s	remaining: 42.6s
# 103:	total: 11.2s	remaining: 42.5s
# 104:	total: 11.3s	remaining: 42.3s
# 105:	total: 11.4s	remaining: 42.2s
# 106:	total: 11.5s	remaining: 42.1s
# 107:	total: 11.6s	remaining: 41.9s
# 108:	total: 11.6s	remaining: 41.8s
# 109:	total: 11.7s	remaining: 41.7s
# 110:	total: 11.8s	remaining: 41.5s
# 111:	total: 11.9s	remaining: 41.4s
# 112:	total: 12s	remaining: 41.2s
# 113:	total: 12.1s	remaining: 41.1s
# 114:	total: 12.3s	remaining: 41s
# 115:	total: 12.3s	remaining: 40.9s
# 116:	total: 12.4s	remaining: 40.7s
# 117:	total: 12.6s	remaining: 40.7s
# 118:	total: 12.7s	remaining: 40.7s
# 119:	total: 12.8s	remaining: 40.7s
# 120:	total: 12.9s	remaining: 40.4s
# 121:	total: 13s	remaining: 40.2s
# 122:	total: 13.1s	remaining: 40.1s
# 123:	total: 13.2s	remaining: 40s
# 124:	total: 13.3s	remaining: 39.9s
# 125:	total: 13.4s	remaining: 39.8s
# 126:	total: 13.5s	remaining: 39.6s
# 127:	total: 13.5s	remaining: 39.4s
# 128:	total: 13.6s	remaining: 39.2s
# 129:	total: 13.7s	remaining: 39s
# 130:	total: 13.8s	remaining: 38.9s
# 131:	total: 13.9s	remaining: 38.7s
# 132:	total: 14s	remaining: 38.6s
# 133:	total: 14.1s	remaining: 38.5s
# 134:	total: 14.2s	remaining: 38.3s
# 135:	total: 14.3s	remaining: 38.1s
# 136:	total: 14.3s	remaining: 38s
# 137:	total: 14.4s	remaining: 37.9s
# 138:	total: 14.5s	remaining: 37.7s
# 139:	total: 14.6s	remaining: 37.5s
# 140:	total: 14.7s	remaining: 37.4s
# 141:	total: 14.8s	remaining: 37.2s
# 142:	total: 14.9s	remaining: 37.1s
# 143:	total: 14.9s	remaining: 36.9s
# 144:	total: 15s	remaining: 36.8s
# 145:	total: 15.1s	remaining: 36.6s
# 146:	total: 15.2s	remaining: 36.4s
# 147:	total: 15.2s	remaining: 36.3s
# 148:	total: 15.3s	remaining: 36.1s
# 149:	total: 15.4s	remaining: 35.9s
# 150:	total: 15.5s	remaining: 35.8s
# 151:	total: 15.6s	remaining: 35.6s
# 152:	total: 15.6s	remaining: 35.5s
# 153:	total: 15.7s	remaining: 35.3s
# 154:	total: 15.8s	remaining: 35.2s
# 155:	total: 15.9s	remaining: 35.1s
# 156:	total: 16s	remaining: 35s
# 157:	total: 16.1s	remaining: 34.8s
# 158:	total: 16.2s	remaining: 34.7s
# 159:	total: 16.3s	remaining: 34.6s
# 160:	total: 16.4s	remaining: 34.5s
# 161:	total: 16.5s	remaining: 34.4s
# 162:	total: 16.6s	remaining: 34.2s
# 163:	total: 16.6s	remaining: 34.1s
# 164:	total: 16.7s	remaining: 34s
# 165:	total: 16.8s	remaining: 33.9s
# 166:	total: 16.9s	remaining: 33.7s
# 167:	total: 17s	remaining: 33.6s
# 168:	total: 17.1s	remaining: 33.5s
# 169:	total: 17.2s	remaining: 33.4s
# 170:	total: 17.3s	remaining: 33.3s
# 171:	total: 17.4s	remaining: 33.1s
# 172:	total: 17.5s	remaining: 33s
# 173:	total: 17.6s	remaining: 32.9s
# 174:	total: 17.6s	remaining: 32.8s
# 175:	total: 17.8s	remaining: 32.7s
# 176:	total: 17.9s	remaining: 32.7s
# 177:	total: 18s	remaining: 32.6s
# 178:	total: 18.2s	remaining: 32.6s
# 179:	total: 18.3s	remaining: 32.5s
# 180:	total: 18.4s	remaining: 32.5s
# 181:	total: 18.6s	remaining: 32.5s
# 182:	total: 18.7s	remaining: 32.4s
# 183:	total: 18.9s	remaining: 32.4s
# 184:	total: 19s	remaining: 32.3s
# 185:	total: 19.1s	remaining: 32.3s
# 186:	total: 19.3s	remaining: 32.3s
# 187:	total: 19.4s	remaining: 32.2s
# 188:	total: 19.6s	remaining: 32.2s
# 189:	total: 19.7s	remaining: 32.2s
# 190:	total: 19.9s	remaining: 32.2s
# 191:	total: 20.1s	remaining: 32.2s
# 192:	total: 20.2s	remaining: 32.1s
# 193:	total: 20.4s	remaining: 32.1s
# 194:	total: 20.5s	remaining: 32.1s
# 195:	total: 20.6s	remaining: 32s
# 196:	total: 20.8s	remaining: 32s
# 197:	total: 20.9s	remaining: 31.9s
# 198:	total: 21.1s	remaining: 31.9s
# 199:	total: 21.3s	remaining: 31.9s
# 200:	total: 21.4s	remaining: 31.9s
# 201:	total: 21.6s	remaining: 31.9s
# 202:	total: 21.7s	remaining: 31.8s
# 203:	total: 21.9s	remaining: 31.8s
# 204:	total: 22.1s	remaining: 31.7s
# 205:	total: 22.2s	remaining: 31.7s
# 206:	total: 22.4s	remaining: 31.7s
# 207:	total: 22.6s	remaining: 31.7s
# 208:	total: 22.7s	remaining: 31.6s
# 209:	total: 22.8s	remaining: 31.5s
# 210:	total: 23s	remaining: 31.5s
# 211:	total: 23.1s	remaining: 31.4s
# 212:	total: 23.3s	remaining: 31.4s
# 213:	total: 23.5s	remaining: 31.4s
# 214:	total: 23.5s	remaining: 31.2s
# 215:	total: 23.6s	remaining: 31.1s
# 216:	total: 23.8s	remaining: 31s
# 217:	total: 23.9s	remaining: 30.9s
# 218:	total: 24s	remaining: 30.8s
# 219:	total: 24.1s	remaining: 30.7s
# 220:	total: 24.2s	remaining: 30.5s
# 221:	total: 24.3s	remaining: 30.4s
# 222:	total: 24.4s	remaining: 30.3s
# 223:	total: 24.5s	remaining: 30.1s
# 224:	total: 24.6s	remaining: 30s
# 225:	total: 24.7s	remaining: 29.9s
# 226:	total: 24.8s	remaining: 29.8s
# 227:	total: 24.9s	remaining: 29.7s
# 228:	total: 25s	remaining: 29.6s
# 229:	total: 25.1s	remaining: 29.5s
# 230:	total: 25.2s	remaining: 29.4s
# 231:	total: 25.3s	remaining: 29.2s
# 232:	total: 25.4s	remaining: 29.1s
# 233:	total: 25.6s	remaining: 29s
# 234:	total: 25.7s	remaining: 29s
# 235:	total: 25.8s	remaining: 28.9s
# 236:	total: 25.9s	remaining: 28.7s
# 237:	total: 26s	remaining: 28.6s
# 238:	total: 26.1s	remaining: 28.5s
# 239:	total: 26.2s	remaining: 28.4s
# 240:	total: 26.3s	remaining: 28.3s
# 241:	total: 26.4s	remaining: 28.2s
# 242:	total: 26.5s	remaining: 28.1s
# 243:	total: 26.6s	remaining: 27.9s
# 244:	total: 26.7s	remaining: 27.8s
# 245:	total: 26.8s	remaining: 27.7s
# 246:	total: 27s	remaining: 27.6s
# 247:	total: 27.1s	remaining: 27.5s
# 248:	total: 27.2s	remaining: 27.4s
# 249:	total: 27.3s	remaining: 27.3s
# 250:	total: 27.4s	remaining: 27.2s
# 251:	total: 27.5s	remaining: 27.1s
# 252:	total: 27.6s	remaining: 27s
# 253:	total: 27.7s	remaining: 26.9s
# 254:	total: 27.8s	remaining: 26.7s
# 255:	total: 27.9s	remaining: 26.6s
# 256:	total: 28s	remaining: 26.5s
# 257:	total: 28.1s	remaining: 26.4s
# 258:	total: 28.2s	remaining: 26.3s
# 259:	total: 28.3s	remaining: 26.2s
# 260:	total: 28.4s	remaining: 26.1s
# 261:	total: 28.6s	remaining: 25.9s
# 262:	total: 28.7s	remaining: 25.8s
# 263:	total: 28.7s	remaining: 25.7s
# 264:	total: 28.8s	remaining: 25.6s
# 265:	total: 28.9s	remaining: 25.5s
# 266:	total: 29.1s	remaining: 25.4s
# 267:	total: 29.2s	remaining: 25.3s
# 268:	total: 29.3s	remaining: 25.2s
# 269:	total: 29.4s	remaining: 25.1s
# 270:	total: 29.5s	remaining: 24.9s
# 271:	total: 29.6s	remaining: 24.8s
# 272:	total: 29.7s	remaining: 24.7s
# 273:	total: 29.8s	remaining: 24.6s
# 274:	total: 29.9s	remaining: 24.5s
# 275:	total: 30s	remaining: 24.4s
# 276:	total: 30.1s	remaining: 24.3s
# 277:	total: 30.2s	remaining: 24.1s
# 278:	total: 30.3s	remaining: 24s
# 279:	total: 30.4s	remaining: 23.9s
# 280:	total: 30.5s	remaining: 23.8s
# 281:	total: 30.6s	remaining: 23.7s
# 282:	total: 30.7s	remaining: 23.6s
# 283:	total: 30.8s	remaining: 23.5s
# 284:	total: 30.9s	remaining: 23.3s
# 285:	total: 31s	remaining: 23.2s
# 286:	total: 31.1s	remaining: 23.1s
# 287:	total: 31.2s	remaining: 23s
# 288:	total: 31.3s	remaining: 22.9s
# 289:	total: 31.4s	remaining: 22.7s
# 290:	total: 31.5s	remaining: 22.6s
# 291:	total: 31.6s	remaining: 22.5s
# 292:	total: 31.7s	remaining: 22.4s
# 293:	total: 31.8s	remaining: 22.3s
# 294:	total: 31.9s	remaining: 22.2s
# 295:	total: 32s	remaining: 22.1s
# 296:	total: 32.1s	remaining: 22s
# 297:	total: 32.2s	remaining: 21.8s
# 298:	total: 32.3s	remaining: 21.7s
# 299:	total: 32.4s	remaining: 21.6s
# 300:	total: 32.5s	remaining: 21.5s
# 301:	total: 32.5s	remaining: 21.3s
# 302:	total: 32.7s	remaining: 21.2s
# 303:	total: 32.8s	remaining: 21.1s
# 304:	total: 32.9s	remaining: 21s
# 305:	total: 33s	remaining: 20.9s
# 306:	total: 33.1s	remaining: 20.8s
# 307:	total: 33.2s	remaining: 20.7s
# 308:	total: 33.2s	remaining: 20.5s
# 309:	total: 33.3s	remaining: 20.4s
# 310:	total: 33.4s	remaining: 20.3s
# 311:	total: 33.5s	remaining: 20.2s
# 312:	total: 33.6s	remaining: 20.1s
# 313:	total: 33.7s	remaining: 20s
# 314:	total: 33.8s	remaining: 19.9s
# 315:	total: 33.9s	remaining: 19.8s
# 316:	total: 34s	remaining: 19.6s
# 317:	total: 34.1s	remaining: 19.5s
# 318:	total: 34.2s	remaining: 19.4s
# 319:	total: 34.3s	remaining: 19.3s
# 320:	total: 34.4s	remaining: 19.2s
# 321:	total: 34.5s	remaining: 19.1s
# 322:	total: 34.6s	remaining: 19s
# 323:	total: 34.7s	remaining: 18.9s
# 324:	total: 34.8s	remaining: 18.8s
# 325:	total: 34.9s	remaining: 18.7s
# 326:	total: 35.1s	remaining: 18.5s
# 327:	total: 35.1s	remaining: 18.4s
# 328:	total: 35.3s	remaining: 18.3s
# 329:	total: 35.4s	remaining: 18.2s
# 330:	total: 35.5s	remaining: 18.1s
# 331:	total: 35.6s	remaining: 18s
# 332:	total: 35.6s	remaining: 17.9s
# 333:	total: 35.7s	remaining: 17.8s
# 334:	total: 35.8s	remaining: 17.6s
# 335:	total: 35.9s	remaining: 17.5s
# 336:	total: 36s	remaining: 17.4s
# 337:	total: 36.1s	remaining: 17.3s
# 338:	total: 36.3s	remaining: 17.2s
# 339:	total: 36.4s	remaining: 17.1s
# 340:	total: 36.5s	remaining: 17s
# 341:	total: 36.6s	remaining: 16.9s
# 342:	total: 36.7s	remaining: 16.8s
# 343:	total: 36.8s	remaining: 16.7s
# 344:	total: 36.9s	remaining: 16.6s
# 345:	total: 37s	remaining: 16.5s
# 346:	total: 37.2s	remaining: 16.4s
# 347:	total: 37.3s	remaining: 16.3s
# 348:	total: 37.4s	remaining: 16.2s
# 349:	total: 37.5s	remaining: 16.1s
# 350:	total: 37.6s	remaining: 16s
# 351:	total: 37.7s	remaining: 15.8s
# 352:	total: 37.8s	remaining: 15.7s
# 353:	total: 37.9s	remaining: 15.6s
# 354:	total: 38s	remaining: 15.5s
# 355:	total: 38.1s	remaining: 15.4s
# 356:	total: 38.1s	remaining: 15.3s
# 357:	total: 38.2s	remaining: 15.2s
# 358:	total: 38.3s	remaining: 15s
# 359:	total: 38.4s	remaining: 14.9s
# 360:	total: 38.5s	remaining: 14.8s
# 361:	total: 38.6s	remaining: 14.7s
# 362:	total: 38.7s	remaining: 14.6s
# 363:	total: 38.8s	remaining: 14.5s
# 364:	total: 38.9s	remaining: 14.4s
# 365:	total: 39s	remaining: 14.3s
# 366:	total: 39.1s	remaining: 14.2s
# 367:	total: 39.2s	remaining: 14.1s
# 368:	total: 39.3s	remaining: 14s
# 369:	total: 39.4s	remaining: 13.8s
# 370:	total: 39.5s	remaining: 13.7s
# 371:	total: 39.6s	remaining: 13.6s
# 372:	total: 39.7s	remaining: 13.5s
# 373:	total: 39.8s	remaining: 13.4s
# 374:	total: 39.9s	remaining: 13.3s
# 375:	total: 40s	remaining: 13.2s
# 376:	total: 40.1s	remaining: 13.1s
# 377:	total: 40.3s	remaining: 13s
# 378:	total: 40.4s	remaining: 12.9s
# 379:	total: 40.4s	remaining: 12.8s
# 380:	total: 40.5s	remaining: 12.7s
# 381:	total: 40.6s	remaining: 12.5s
# 382:	total: 40.7s	remaining: 12.4s
# 383:	total: 40.9s	remaining: 12.3s
# 384:	total: 41s	remaining: 12.2s
# 385:	total: 41.1s	remaining: 12.1s
# 386:	total: 41.3s	remaining: 12s
# ...
# 55:	total: 6.01s	remaining: 47.7s
# 56:	total: 6.18s	remaining: 48s
# 57:	total: 6.24s	remaining: 47.5s
# 58:	total: 6.31s	remaining: 47.2s
# 59:	total: 6.39s	remaining: 46.9s
# 60:	total: 6.47s	remaining: 46.6s
# 61:	total: 6.56s	remaining: 46.4s
# 62:	total: 6.65s	remaining: 46.1s
# 63:	total: 6.75s	remaining: 46s
# 64:	total: 6.83s	remaining: 45.7s
# 65:	total: 6.92s	remaining: 45.5s
# 66:	total: 7.02s	remaining: 45.4s
# 67:	total: 7.12s	remaining: 45.2s
# 68:	total: 7.21s	remaining: 45s
# 69:	total: 7.3s	remaining: 44.9s
# 70:	total: 7.4s	remaining: 44.7s
# 71:	total: 7.49s	remaining: 44.5s
# 72:	total: 7.58s	remaining: 44.4s
# 73:	total: 7.67s	remaining: 44.1s
# 74:	total: 7.74s	remaining: 43.9s
# 75:	total: 7.84s	remaining: 43.7s
# 76:	total: 7.92s	remaining: 43.5s
# 77:	total: 8.01s	remaining: 43.3s
# 78:	total: 8.09s	remaining: 43.1s
# 79:	total: 8.16s	remaining: 42.9s
# 80:	total: 8.24s	remaining: 42.6s
# 81:	total: 8.32s	remaining: 42.4s
# 82:	total: 8.46s	remaining: 42.5s
# 83:	total: 8.69s	remaining: 43.1s
# 84:	total: 8.76s	remaining: 42.8s
# 85:	total: 8.83s	remaining: 42.5s
# 86:	total: 8.92s	remaining: 42.3s
# 87:	total: 9.02s	remaining: 42.2s
# 88:	total: 9.13s	remaining: 42.2s
# 89:	total: 9.24s	remaining: 42.1s
# 90:	total: 9.33s	remaining: 41.9s
# 91:	total: 9.42s	remaining: 41.8s
# 92:	total: 9.5s	remaining: 41.6s
# 93:	total: 9.58s	remaining: 41.4s
# 94:	total: 9.69s	remaining: 41.3s
# 95:	total: 9.8s	remaining: 41.3s
# 96:	total: 9.9s	remaining: 41.1s
# 97:	total: 10s	remaining: 41s
# 98:	total: 10.1s	remaining: 40.9s
# 99:	total: 10.2s	remaining: 40.8s
# 100:	total: 10.3s	remaining: 40.7s
# 101:	total: 10.4s	remaining: 40.6s
# 102:	total: 10.5s	remaining: 40.4s
# 103:	total: 10.6s	remaining: 40.3s
# 104:	total: 10.7s	remaining: 40.1s
# 105:	total: 10.7s	remaining: 40s
# 106:	total: 10.8s	remaining: 39.8s
# 107:	total: 10.9s	remaining: 39.7s
# 108:	total: 11s	remaining: 39.6s
# 109:	total: 11.1s	remaining: 39.5s
# 110:	total: 11.2s	remaining: 39.4s
# 111:	total: 11.5s	remaining: 40s
# 112:	total: 11.6s	remaining: 39.9s
# 113:	total: 11.7s	remaining: 39.6s
# 114:	total: 11.8s	remaining: 39.5s
# 115:	total: 11.9s	remaining: 39.4s
# 116:	total: 12s	remaining: 39.3s
# 117:	total: 12.1s	remaining: 39.1s
# 118:	total: 12.2s	remaining: 38.9s
# 119:	total: 12.3s	remaining: 38.8s
# 120:	total: 12.4s	remaining: 38.7s
# 121:	total: 12.4s	remaining: 38.6s
# 122:	total: 12.5s	remaining: 38.5s
# 123:	total: 12.6s	remaining: 38.3s
# 124:	total: 12.8s	remaining: 38.3s
# 125:	total: 12.8s	remaining: 38.1s
# 126:	total: 12.9s	remaining: 38s
# 127:	total: 13s	remaining: 37.9s
# 128:	total: 13.1s	remaining: 37.8s
# 129:	total: 13.2s	remaining: 37.7s
# 130:	total: 13.3s	remaining: 37.6s
# 131:	total: 13.4s	remaining: 37.4s
# 132:	total: 13.5s	remaining: 37.3s
# 133:	total: 13.6s	remaining: 37.2s
# 134:	total: 13.7s	remaining: 37.1s
# 135:	total: 13.8s	remaining: 37s
# 136:	total: 13.9s	remaining: 36.8s
# 137:	total: 14s	remaining: 36.7s
# 138:	total: 14.1s	remaining: 36.6s
# 139:	total: 14.2s	remaining: 36.5s
# 140:	total: 14.3s	remaining: 36.5s
# 141:	total: 14.6s	remaining: 36.9s
# 142:	total: 14.7s	remaining: 36.7s
# 143:	total: 14.8s	remaining: 36.6s
# 144:	total: 14.9s	remaining: 36.5s
# 145:	total: 15s	remaining: 36.3s
# 146:	total: 15.1s	remaining: 36.1s
# 147:	total: 15.1s	remaining: 36s
# 148:	total: 15.2s	remaining: 35.9s
# 149:	total: 15.4s	remaining: 35.8s
# 150:	total: 15.4s	remaining: 35.7s
# 151:	total: 15.5s	remaining: 35.6s
# 152:	total: 15.7s	remaining: 35.5s
# 153:	total: 15.8s	remaining: 35.4s
# 154:	total: 15.9s	remaining: 35.3s
# 155:	total: 16s	remaining: 35.2s
# 156:	total: 16.1s	remaining: 35.1s
# 157:	total: 16.1s	remaining: 35s
# 158:	total: 16.3s	remaining: 34.9s
# 159:	total: 16.4s	remaining: 34.8s
# 160:	total: 16.5s	remaining: 34.7s
# 161:	total: 16.6s	remaining: 34.6s
# 162:	total: 16.6s	remaining: 34.4s
# 163:	total: 16.7s	remaining: 34.3s
# 164:	total: 16.8s	remaining: 34.2s
# 165:	total: 16.9s	remaining: 34.1s
# 166:	total: 17s	remaining: 34s
# 167:	total: 17.3s	remaining: 34.3s
# 168:	total: 17.5s	remaining: 34.2s
# 169:	total: 17.6s	remaining: 34.1s
# 170:	total: 17.7s	remaining: 34s
# 171:	total: 17.7s	remaining: 33.8s
# 172:	total: 17.9s	remaining: 33.8s
# 173:	total: 17.9s	remaining: 33.6s
# 174:	total: 18s	remaining: 33.5s
# 175:	total: 18.1s	remaining: 33.3s
# 176:	total: 18.2s	remaining: 33.2s
# 177:	total: 18.3s	remaining: 33.2s
# 178:	total: 18.5s	remaining: 33.2s
# 179:	total: 18.6s	remaining: 33.1s
# 180:	total: 18.8s	remaining: 33.1s
# 181:	total: 19s	remaining: 33.1s
# 182:	total: 19.1s	remaining: 33.1s
# 183:	total: 19.2s	remaining: 33s
# 184:	total: 19.4s	remaining: 33s
# 185:	total: 19.5s	remaining: 33s
# 186:	total: 19.7s	remaining: 32.9s
# 187:	total: 19.8s	remaining: 32.9s
# 188:	total: 20s	remaining: 32.9s
# 189:	total: 20.1s	remaining: 32.8s
# 190:	total: 20.3s	remaining: 32.8s
# 191:	total: 20.4s	remaining: 32.7s
# 192:	total: 20.6s	remaining: 32.7s
# 193:	total: 20.7s	remaining: 32.6s
# 194:	total: 20.8s	remaining: 32.6s
# 195:	total: 21s	remaining: 32.6s
# 196:	total: 21.1s	remaining: 32.5s
# 197:	total: 21.3s	remaining: 32.5s
# 198:	total: 21.5s	remaining: 32.6s
# 199:	total: 21.6s	remaining: 32.4s
# 200:	total: 21.7s	remaining: 32.3s
# 201:	total: 21.8s	remaining: 32.1s
# 202:	total: 21.8s	remaining: 32s
# 203:	total: 21.9s	remaining: 31.8s
# 204:	total: 22s	remaining: 31.7s
# 205:	total: 22.1s	remaining: 31.6s
# 206:	total: 22.2s	remaining: 31.5s
# 207:	total: 22.3s	remaining: 31.3s
# 208:	total: 22.4s	remaining: 31.2s
# 209:	total: 22.5s	remaining: 31.1s
# 210:	total: 22.6s	remaining: 31s
# 211:	total: 22.7s	remaining: 30.9s
# 212:	total: 22.8s	remaining: 30.7s
# 213:	total: 22.9s	remaining: 30.6s
# 214:	total: 23s	remaining: 30.5s
# 215:	total: 23.1s	remaining: 30.4s
# 216:	total: 23.2s	remaining: 30.3s
# 217:	total: 23.3s	remaining: 30.1s
# 218:	total: 23.4s	remaining: 30s
# 219:	total: 23.5s	remaining: 29.9s
# 220:	total: 23.6s	remaining: 29.8s
# 221:	total: 23.7s	remaining: 29.7s
# 222:	total: 23.8s	remaining: 29.6s
# 223:	total: 23.9s	remaining: 29.5s
# 224:	total: 24s	remaining: 29.4s
# 225:	total: 24.3s	remaining: 29.4s
# 226:	total: 24.4s	remaining: 29.3s
# 227:	total: 24.4s	remaining: 29.2s
# 228:	total: 24.5s	remaining: 29s
# 229:	total: 24.6s	remaining: 28.9s
# 230:	total: 24.7s	remaining: 28.8s
# 231:	total: 24.8s	remaining: 28.7s
# 232:	total: 24.9s	remaining: 28.5s
# 233:	total: 25s	remaining: 28.4s
# 234:	total: 25.1s	remaining: 28.3s
# 235:	total: 25.2s	remaining: 28.2s
# 236:	total: 25.3s	remaining: 28.1s
# 237:	total: 25.4s	remaining: 28s
# 238:	total: 25.5s	remaining: 27.9s
# 239:	total: 25.6s	remaining: 27.7s
# 240:	total: 25.7s	remaining: 27.6s
# 241:	total: 25.8s	remaining: 27.5s
# 242:	total: 25.9s	remaining: 27.4s
# 243:	total: 26s	remaining: 27.3s
# 244:	total: 26.1s	remaining: 27.1s
# 245:	total: 26.2s	remaining: 27s
# 246:	total: 26.3s	remaining: 26.9s
# 247:	total: 26.4s	remaining: 26.8s
# 248:	total: 26.5s	remaining: 26.7s
# 249:	total: 26.5s	remaining: 26.5s
# 250:	total: 26.6s	remaining: 26.4s
# 251:	total: 26.7s	remaining: 26.3s
# 252:	total: 26.8s	remaining: 26.2s
# 253:	total: 27s	remaining: 26.1s
# 254:	total: 27.1s	remaining: 26s
# 255:	total: 27.2s	remaining: 25.9s
# 256:	total: 27.3s	remaining: 25.8s
# 257:	total: 27.5s	remaining: 25.8s
# 258:	total: 27.6s	remaining: 25.7s
# 259:	total: 27.7s	remaining: 25.5s
# 260:	total: 27.7s	remaining: 25.4s
# 261:	total: 27.8s	remaining: 25.3s
# 262:	total: 27.9s	remaining: 25.1s
# 263:	total: 28s	remaining: 25s
# 264:	total: 28.1s	remaining: 24.9s
# 265:	total: 28.2s	remaining: 24.8s
# 266:	total: 28.3s	remaining: 24.7s
# 267:	total: 28.4s	remaining: 24.6s
# 268:	total: 28.5s	remaining: 24.5s
# 269:	total: 28.6s	remaining: 24.4s
# 270:	total: 28.7s	remaining: 24.2s
# 271:	total: 28.8s	remaining: 24.1s
# 272:	total: 28.9s	remaining: 24s
# 273:	total: 29s	remaining: 23.9s
# 274:	total: 29.1s	remaining: 23.8s
# 275:	total: 29.2s	remaining: 23.7s
# 276:	total: 29.2s	remaining: 23.5s
# 277:	total: 29.3s	remaining: 23.4s
# 278:	total: 29.4s	remaining: 23.3s
# 279:	total: 29.5s	remaining: 23.2s
# 280:	total: 29.6s	remaining: 23.1s
# 281:	total: 29.7s	remaining: 23s
# 282:	total: 29.8s	remaining: 22.9s
# 283:	total: 29.9s	remaining: 22.8s
# 284:	total: 30s	remaining: 22.7s
# 285:	total: 30.2s	remaining: 22.6s
# 286:	total: 30.3s	remaining: 22.5s
# 287:	total: 30.4s	remaining: 22.4s
# 288:	total: 30.5s	remaining: 22.3s
# 289:	total: 30.7s	remaining: 22.2s
# 290:	total: 30.8s	remaining: 22.1s
# 291:	total: 30.9s	remaining: 22s
# 292:	total: 31s	remaining: 21.9s
# 293:	total: 31s	remaining: 21.8s
# 294:	total: 31.1s	remaining: 21.6s
# 295:	total: 31.2s	remaining: 21.5s
# 296:	total: 31.3s	remaining: 21.4s
# 297:	total: 31.4s	remaining: 21.3s
# 298:	total: 31.5s	remaining: 21.2s
# 299:	total: 31.6s	remaining: 21.1s
# 300:	total: 31.7s	remaining: 21s
# 301:	total: 31.8s	remaining: 20.9s
# 302:	total: 31.9s	remaining: 20.8s
# 303:	total: 32.1s	remaining: 20.7s
# 304:	total: 32.2s	remaining: 20.6s
# 305:	total: 32.3s	remaining: 20.5s
# 306:	total: 32.4s	remaining: 20.3s
# 307:	total: 32.5s	remaining: 20.2s
# 308:	total: 32.6s	remaining: 20.2s
# 309:	total: 32.8s	remaining: 20.1s
# 310:	total: 32.9s	remaining: 20s
# 311:	total: 33.1s	remaining: 19.9s
# 312:	total: 33.2s	remaining: 19.8s
# 313:	total: 33.4s	remaining: 19.8s
# 314:	total: 33.5s	remaining: 19.7s
# 315:	total: 33.7s	remaining: 19.6s
# 316:	total: 33.9s	remaining: 19.5s
# 317:	total: 34s	remaining: 19.5s
# 318:	total: 34.2s	remaining: 19.4s
# 319:	total: 34.4s	remaining: 19.3s
# 320:	total: 34.5s	remaining: 19.3s
# 321:	total: 34.7s	remaining: 19.2s
# 322:	total: 34.8s	remaining: 19.1s
# 323:	total: 35s	remaining: 19s
# 324:	total: 35.2s	remaining: 18.9s
# 325:	total: 35.3s	remaining: 18.9s
# 326:	total: 35.5s	remaining: 18.8s
# 327:	total: 35.7s	remaining: 18.7s
# 328:	total: 35.8s	remaining: 18.6s
# 329:	total: 36s	remaining: 18.5s
# 330:	total: 36.1s	remaining: 18.5s
# 331:	total: 36.3s	remaining: 18.4s
# 332:	total: 36.4s	remaining: 18.3s
# 333:	total: 36.6s	remaining: 18.2s
# 334:	total: 36.8s	remaining: 18.1s
# 335:	total: 36.9s	remaining: 18s
# 336:	total: 37.1s	remaining: 17.9s
# 337:	total: 37.2s	remaining: 17.9s
# 338:	total: 37.4s	remaining: 17.8s
# 339:	total: 37.6s	remaining: 17.7s
# 340:	total: 37.7s	remaining: 17.6s
# 341:	total: 37.9s	remaining: 17.5s
# 342:	total: 38s	remaining: 17.4s
# 343:	total: 38.2s	remaining: 17.3s
# 344:	total: 38.3s	remaining: 17.2s
# 345:	total: 38.4s	remaining: 17.1s
# 346:	total: 38.5s	remaining: 17s
# 347:	total: 38.6s	remaining: 16.9s
# 348:	total: 38.7s	remaining: 16.8s
# 349:	total: 38.8s	remaining: 16.6s
# 350:	total: 39s	remaining: 16.5s
# 351:	total: 39.1s	remaining: 16.4s
# 352:	total: 39.2s	remaining: 16.3s
# 353:	total: 39.2s	remaining: 16.2s
# 354:	total: 39.3s	remaining: 16.1s
# 355:	total: 39.4s	remaining: 15.9s
# 356:	total: 39.5s	remaining: 15.8s
# 357:	total: 39.6s	remaining: 15.7s
# 358:	total: 39.7s	remaining: 15.6s
# 359:	total: 39.8s	remaining: 15.5s
# 360:	total: 39.9s	remaining: 15.4s
# 361:	total: 40s	remaining: 15.2s
# 362:	total: 40.1s	remaining: 15.1s
# 363:	total: 40.1s	remaining: 15s
# 364:	total: 40.2s	remaining: 14.9s
# 365:	total: 40.3s	remaining: 14.8s
# 366:	total: 40.4s	remaining: 14.6s
# 367:	total: 40.5s	remaining: 14.5s
# 368:	total: 40.6s	remaining: 14.4s
# 369:	total: 40.7s	remaining: 14.3s
# 370:	total: 40.8s	remaining: 14.2s
# 371:	total: 40.9s	remaining: 14.1s
# 372:	total: 41s	remaining: 14s
# 373:	total: 41.1s	remaining: 13.8s
# 374:	total: 41.2s	remaining: 13.7s
# 375:	total: 41.3s	remaining: 13.6s
# 376:	total: 41.4s	remaining: 13.5s
# 377:	total: 41.5s	remaining: 13.4s
# 378:	total: 41.6s	remaining: 13.3s
# 379:	total: 41.7s	remaining: 13.2s
# 380:	total: 41.8s	remaining: 13s
# 381:	total: 41.9s	remaining: 12.9s
# 382:	total: 41.9s	remaining: 12.8s
# 383:	total: 42s	remaining: 12.7s
# 384:	total: 42.1s	remaining: 12.6s
# 385:	total: 42.3s	remaining: 12.5s
# 386:	total: 42.4s	remaining: 12.4s
# 387:	total: 42.5s	remaining: 12.3s
# 388:	total: 42.6s	remaining: 12.2s
# 389:	total: 42.7s	remaining: 12s
# 390:	total: 42.8s	remaining: 11.9s
# 391:	total: 42.9s	remaining: 11.8s
# 392:	total: 43s	remaining: 11.7s
# 393:	total: 43.1s	remaining: 11.6s
# 394:	total: 43.2s	remaining: 11.5s
# 395:	total: 43.3s	remaining: 11.4s
# 396:	total: 43.4s	remaining: 11.3s
# 397:	total: 43.5s	remaining: 11.2s
# 398:	total: 43.6s	remaining: 11s
# 399:	total: 43.7s	remaining: 10.9s
# 400:	total: 43.8s	remaining: 10.8s
# 401:	total: 43.9s	remaining: 10.7s
# 402:	total: 44s	remaining: 10.6s
# 403:	total: 44.1s	remaining: 10.5s
# 404:	total: 44.2s	remaining: 10.4s
# 405:	total: 44.3s	remaining: 10.3s
# 406:	total: 44.4s	remaining: 10.1s
# 407:	total: 44.5s	remaining: 10s
# 408:	total: 44.5s	remaining: 9.91s
# 409:	total: 44.6s	remaining: 9.8s
# 410:	total: 44.7s	remaining: 9.68s
# 411:	total: 44.8s	remaining: 9.56s
# 412:	total: 44.9s	remaining: 9.45s
# 413:	total: 44.9s	remaining: 9.34s
# 414:	total: 45s	remaining: 9.23s
# 415:	total: 45.2s	remaining: 9.12s
# 416:	total: 45.3s	remaining: 9.01s
# 417:	total: 45.4s	remaining: 8.9s
# 418:	total: 45.4s	remaining: 8.78s
# 419:	total: 45.5s	remaining: 8.67s
# 420:	total: 45.6s	remaining: 8.56s
# 421:	total: 45.7s	remaining: 8.45s
# 422:	total: 45.8s	remaining: 8.34s
# 423:	total: 45.9s	remaining: 8.23s
# 424:	total: 46s	remaining: 8.12s
# 425:	total: 46.1s	remaining: 8.01s
# 426:	total: 46.2s	remaining: 7.9s
# 427:	total: 46.3s	remaining: 7.79s
# 428:	total: 46.4s	remaining: 7.67s
# 429:	total: 46.4s	remaining: 7.56s
# 430:	total: 46.5s	remaining: 7.45s
# 431:	total: 46.6s	remaining: 7.34s
# 432:	total: 46.7s	remaining: 7.22s
# 433:	total: 46.8s	remaining: 7.11s
# 434:	total: 46.9s	remaining: 7s
# 435:	total: 47s	remaining: 6.9s
# 436:	total: 47.1s	remaining: 6.79s
# 437:	total: 47.3s	remaining: 6.69s
# 438:	total: 47.4s	remaining: 6.59s
# 439:	total: 47.6s	remaining: 6.49s
# 440:	total: 47.7s	remaining: 6.38s
# 441:	total: 47.9s	remaining: 6.28s
# 442:	total: 48s	remaining: 6.18s
# 443:	total: 48.2s	remaining: 6.07s
# 444:	total: 48.3s	remaining: 5.97s
# 445:	total: 48.5s	remaining: 5.87s
# 446:	total: 48.7s	remaining: 5.78s
# 447:	total: 49s	remaining: 5.69s
# 448:	total: 49.3s	remaining: 5.6s
# 449:	total: 49.4s	remaining: 5.49s
# 450:	total: 49.6s	remaining: 5.39s
# 451:	total: 49.7s	remaining: 5.28s
# 452:	total: 49.8s	remaining: 5.17s
# 453:	total: 49.9s	remaining: 5.06s
# 454:	total: 50s	remaining: 4.95s
# 455:	total: 50.1s	remaining: 4.83s
# 456:	total: 50.2s	remaining: 4.72s
# 457:	total: 50.3s	remaining: 4.61s
# 458:	total: 50.4s	remaining: 4.5s
# 459:	total: 50.4s	remaining: 4.39s
# 460:	total: 50.5s	remaining: 4.28s
# 461:	total: 50.6s	remaining: 4.17s
# 462:	total: 50.8s	remaining: 4.06s
# 463:	total: 50.9s	remaining: 3.94s
# 464:	total: 50.9s	remaining: 3.83s
# 465:	total: 51s	remaining: 3.72s
# 466:	total: 51.1s	remaining: 3.61s
# 467:	total: 51.2s	remaining: 3.5s
# 468:	total: 51.3s	remaining: 3.39s
# 469:	total: 51.4s	remaining: 3.28s
# 470:	total: 51.5s	remaining: 3.17s
# 471:	total: 51.6s	remaining: 3.06s
# 472:	total: 51.6s	remaining: 2.95s
# 473:	total: 51.7s	remaining: 2.84s
# 474:	total: 51.8s	remaining: 2.73s
# 475:	total: 51.9s	remaining: 2.62s
# 476:	total: 52s	remaining: 2.51s
# 477:	total: 52.1s	remaining: 2.4s
# 478:	total: 52.2s	remaining: 2.29s
# 479:	total: 52.3s	remaining: 2.18s
# 480:	total: 52.4s	remaining: 2.07s
# 481:	total: 52.5s	remaining: 1.96s
# 482:	total: 52.6s	remaining: 1.85s
# 483:	total: 52.7s	remaining: 1.74s
# 484:	total: 52.8s	remaining: 1.63s
# 485:	total: 52.9s	remaining: 1.52s
# 486:	total: 53s	remaining: 1.41s
# 487:	total: 53.1s	remaining: 1.3s
# 488:	total: 53.2s	remaining: 1.2s
# 489:	total: 53.3s	remaining: 1.09s
# 490:	total: 53.4s	remaining: 979ms
# 491:	total: 53.5s	remaining: 871ms
# 492:	total: 53.6s	remaining: 762ms
# 493:	total: 53.8s	remaining: 653ms
# 494:	total: 53.9s	remaining: 544ms
# 495:	total: 54s	remaining: 435ms
# 496:	total: 54s	remaining: 326ms
# 497:	total: 54.1s	remaining: 217ms
# 498:	total: 54.2s	remaining: 109ms
# 499:	total: 54.3s	remaining: 0us
# GridSearchCV(cv=StratifiedKFold(n_splits=10, random_state=42, shuffle=True),
#              estimator=<catboost.core.CatBoostClassifier object at 0x0000028C5F3C2330>,
#              n_jobs=1,
#              param_grid={'bootstrap_type': ['Bernoulli'], 'border_count': [128],
#                          'depth': [6], 'eval_metric': ['AUC'],
#                          'grow_policy': ['SymmetricTree'], 'iterations': [500],
#                          'l2_leaf_reg': [3], 'learning_rate': [0.05],
#                          'od_type': ['Iter'], 'od_wait': [30],
#                          'subsample': [0.8]},
#              scoring='f1_weighted', verbose=1)

# %%
# Get best parameters
best_params = grid_search.best_params_

# %%
# Create new model with best parameters
best_model = CatBoostClassifier(**best_params, silent=True, random_state=42)

# %%
skf_eval = StratifiedKFold(n_splits=10, shuffle=True, random_state=42)

accuracies = []
recalls = []
precisions = []
f1_scores = []
roc_aucs = []

for fold, (train_idx, val_idx) in enumerate(skf_eval.split(x_tr_resample, y_tr_resample)):
    # Split data
    X_train_fold = x_tr_resample.iloc[train_idx]
    y_train_fold = y_tr_resample[train_idx]
    X_val_fold = x_tr_resample.iloc[val_idx]
    y_val_fold = y_tr_resample[val_idx]
    
    # Train model
    best_model.fit(X_train_fold, y_train_fold)
    
    # Make predictions
    y_pred_fold = best_model.predict(X_val_fold)
    y_pred_proba_fold = best_model.predict_proba(X_val_fold)[:, 1]
    
    # Calculate metrics
    accuracies.append(accuracy_score(y_val_fold, y_pred_fold))
    recalls.append(recall_score(y_val_fold, y_pred_fold, average='weighted'))
    precisions.append(precision_score(y_val_fold, y_pred_fold, average='weighted'))
    f1_scores.append(f1_score(y_val_fold, y_pred_fold, average='weighted'))
    roc_aucs.append(roc_auc_score(y_val_fold, y_pred_proba_fold))

# %%
best_model.fit(x_tr_resample, y_tr_resample)
y_pred_test = best_model.predict(X_test)

y_pred_test_proba = best_model.predict_proba(X_test)[:, 1]

y_train_pred = best_model.predict(x_tr_resample)

# %%
print("CatBoost Results:")
print("-" * 50)
print("Best Parameters:", best_params)
print("\nCross-validation Results (10-fold):")
print(f"Accuracy    : {np.mean(accuracies)*100:.2f}% (+/- {np.std(accuracies)*100:.2f}%)")
print(f"Recall      : {np.mean(recalls)*100:.2f}% (+/- {np.std(recalls)*100:.2f}%)")
print(f"Precision   : {np.mean(precisions)*100:.2f}% (+/- {np.std(precisions)*100:.2f}%)")
print(f"F1-Score    : {np.mean(f1_scores)*100:.2f}% (+/- {np.std(f1_scores)*100:.2f}%)")

print("\nTrain Set Results:")
print(f"Accuracy    : {accuracy_score(y_tr_resample, y_train_pred)*100:.2f}%")
print(f"Recall      : {recall_score(y_tr_resample, y_train_pred, average='weighted')*100:.2f}%")
print(f"Precision   : {precision_score(y_tr_resample, y_train_pred, average='weighted')*100:.2f}%")
print(f"F1-Score    : {f1_score(y_tr_resample, y_train_pred, average='weighted')*100:.2f}%")

print("\nTest Set Results:")
print(f"Accuracy    : {accuracy_score(y_test, y_pred_test)*100:.2f}%")
print(f"Recall      : {recall_score(y_test, y_pred_test, average='weighted')*100:.2f}%")
print(f"Precision   : {precision_score(y_test, y_pred_test, average='weighted')*100:.2f}%")
print(f"F1-Score    : {f1_score(y_test, y_pred_test, average='weighted')*100:.2f}%")
print(f"ROC AUC     : {roc_auc_score(y_test, y_pred_test_proba)*100:.2f}%")
print("-" * 50)
# Out:
# CatBoost Results:
# --------------------------------------------------
# Best Parameters: {'bootstrap_type': 'Bernoulli', 'border_count': 128, 'depth': 6, 'eval_metric': 'AUC', 'grow_policy': 'SymmetricTree', 'iterations': 500, 'l2_leaf_reg': 3, 'learning_rate': 0.05, 'od_type': 'Iter', 'od_wait': 30, 'subsample': 0.8}
#
# Cross-validation Results (10-fold):
# Accuracy    : 99.43% (+/- 0.14%)
# Recall      : 99.43% (+/- 0.14%)
# Precision   : 99.43% (+/- 0.14%)
# F1-Score    : 99.43% (+/- 0.14%)
#
# Train Set Results:
# Accuracy    : 99.93%
# Recall      : 99.93%
# Precision   : 99.93%
# F1-Score    : 99.93%
#
# Test Set Results:
# Accuracy    : 99.34%
# Recall      : 99.34%
# Precision   : 99.34%
# F1-Score    : 99.34%
# ROC AUC     : 99.93%
# --------------------------------------------------
